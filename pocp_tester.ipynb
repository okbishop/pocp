# %% [markdown]
# '''
# pocp - automatic monitoring of New Zealand planned outage and coordination process
#     Copyright (C) 2013 David Hume, Electricty Authority, New Zealand.
#
# Initial POCP version control script currently running with the following two crontab entries:
#
# 5 1,7,13,19 * * * /usr/bin/python /home/humed/python/POCP/pocp.py --pocp_pass="password" --dw_pass="password" >> /home/humed/python/POCP/pocp_cron.log 2>&1
# 10 1,7,13,19 * * * cd /home/humed/python/POCP && /usr/local/bin/git commit -a -m "Cron commit at $(date +\%Y_\%m_\%d_\%H)" >> /home/hume$
#
# The first part runs this python script every 6 hours at five minutes past the hour, for the hours, 1am,7am,1pm and 7pm.
# This script is currently basic and needs to be rewritten in a proper class format with exception handling etc, (future work)
# The basic idea is: 1) grab all POCP data (confirmed/tentative/cancelled) for Transmission/Generation, and,
#                       Direct Connects looking back 6 months and forward 6 months from the current date
#                    2) add this data to the all time pocp data history and remove duplicates
#                    3) save this to a text file, in this case, pocp_all.csv
#                    4) modify the generation POCP data to be more usefull historically - see code below
#                    5) create time series data with POCP_to_timeseries function
#                    6) output csv files for interative plotting with d3/javascript, see, pocp.html
#
# D J Hume, 8 May, 2013
# '''

# %% [markdown]
# TODO/Ideas: This notebook is a work in progress attempting th develop and munge the POCP data into better form for plotting
#     with d3/crossfilter
#
# A couple of current ideas before I forget (18/9/2013)
# Generation, live stack plots of generation outages with time/NI/SI/gen_type
# Update total stack plots (as we used to do)
#
# Transmission:
#     Labeled line plots of current transmission outages with time, sorted by duration, so we have the long duration outahes at the bottom
#     Kinda similar to above...

# %%
import pandas as pd
import mechanize
from bs4 import BeautifulSoup
import os,sys
from datetime import date, datetime, time, timedelta
from io import StringIO
import pyodbc
import pandas.io.sql as sql
from dateutil.parser import parse
import matplotlib as mpl
import matplotlib.pyplot as plt
import argparse
import numpy as np
import EAtools as ea

# %%
#############################################################################################################################################################################        
#Setup command line option and argument parsing
#############################################################################################################################################################################        
parser = argparse.ArgumentParser(add_help=False)
parser.add_argument('--pocp_host', action="store",dest='pocp_host',default='http://pocp.redspider.co.nz/')
parser.add_argument('--pocp_user', action="store",dest='pocp_user',default='david.hume')
parser.add_argument('--pocp_pass', action="store",dest='pocp_pass')
parser.add_argument('--dw_user', action="store",dest='dw_user',default='linux_user')
parser.add_argument('--dw_pass', action="store",dest='dw_pass')
parser.add_argument('--pocp_path', action="store",dest='pocp_path',default='/home/humed/python/POCP/')

IPy_notebook = True
if IPy_notebook == False:
    cmd_line = parser.parse_args()
if IPy_notebook == True:
    ea.set_options()
    class cmd_line():
        def __init__(self,pocp_host,pocp_user,pocp_pass,dw_user,dw_pass,pocp_path):
            self.pocp_host = pocp_host
            self.pocp_user = pocp_user
            self.pocp_pass = pocp_pass
            self.dw_user = dw_user
            self.dw_pass = dw_pass
            self.pocp_path = pocp_path
            
            
    cmd_line=cmd_line('http://pocp.redspider.co.nz/','username_here','password_here','linux_user','linux','/home/humed/python/POCP/')

# %%
############################################################################################################################################################################        
#Download the the last year of ther POCP database, append to historical data and spit out a csv
#############################################################################################################################################################################        

class POCP(object):
    '''This is the POCP class'''
    def __init__(self,cmd_line,start_time=None,end_time=None):
        self.cmd_line = cmd_line
        self.start_time = start_time
        self.end_time = end_time
        self.current_download = None
        self.con = ea.DW_connect(linux=True)
        self.additional_island_mappings= {'ANC':'NI','KAG':'NI','KTW':'NI','NAP':'NI','PRI':'NI',
                                              'TAA':'NI','TAP':'NI','TUK':'NI','WHL':'SI','WWD':'NI','THI':'NI','n/a':nan}
        self.additional_gentype_mappings= {'ABY': 'Hydro','ANC': 'Thermal','BLN': 'Hydro','BPE': 'Wind',\
                                               'BRB': 'Thermal','CST': 'Hydro','DOB': 'Hydro','HAM': 'Thermal',\
                                               'HKK': 'Hydro','HUI': 'Hydro','HWB': 'Wind','KAG': 'Geothermal',\
                                               'KOE':'Geothermal','KTW': 'Hydro','KUM': 'Hydro','LTN': 'Wind',\
                                               'NSY': 'Hydro','PRI': 'Hydro','TAA': 'Geothermal','TAP': 'Wind',\
                                               'TGA': 'Hydro','TUK': 'Wind','WHL': 'Wind','THI':'Geothermal','n/a':nan}
    #mappings
    def generation_type_map(self):
        gens = sql.read_frame("Select * from com.MAP_Generating_plant", self.con)
        gens = gens[gens['Connection_Type']=='G']
        GT = gens.set_index('POC').Generation_Type.reset_index()
        GT['POC'] = GT.POC.map(lambda x: x[0:3])
        GT = GT.drop_duplicates().set_index('POC').Generation_Type
        GT.ix['KAW'] = 'Geothermal'
        self.GT = GT.to_dict()
        self.GT = dict(self.GT.items()+self.additional_gentype_mappings.items())
        
    def island_map(self):
        island = sql.read_frame("Select * from com.MAP_PNode_to_POC_and_island", self.con)
        island_map = island.set_index('POC').Island
        island_map.index=island_map.index.map(lambda x: x[0:3])
        self.island_map = island_map.reset_index().drop_duplicates().set_index('index').Island.to_dict()
        self.island_map = dict(self.island_map.items()+self.additional_island_mappings.items())
    
    def mappings(self,df):
        self.island_map()
        self.generation_type_map()
        df['Generation type'] = df.GIP.map(lambda x: self.GT[x])
        df['Island'] = df.GIP.map(lambda x: self.island_map[x])
        return df   
    
    def dt_convert(self,x):
        if isinstance(x, basestring):
            date = x.split(' ')[0].split('-')
            time = x.split(' ')[1].split(':')
            return datetime(int(date[0]),int(date[1]),int(date[2]),int(time[0]),int(time[1]),int(time[2]))
        else:
            return x

    def set_date_range(self): #Note: downloads from the POCP redspider server appear to be limited to 10000 rows max.
        if self.start_time is None:
            self.strt = (datetime.now() - timedelta(.5*365)) #~6 months back from now
            self.start_time = self.strt.isoformat().split('T')[0].split('-')[2] + '/' + \
                              self.strt.isoformat().split('T')[0].split('-')[1] + '/' + \
                              self.strt.isoformat().split('T')[0].split('-')[0]
        if self.end_time is None:
            self.endt = (datetime.now() + timedelta(0.5*365)) #~6 months into the future
            self.end_time = self.endt.isoformat().split('T')[0].split('-')[2] + '/' + \
                            self.endt.isoformat().split('T')[0].split('-')[1] + '/' + \
                            self.endt.isoformat().split('T')[0].split('-')[0]

    def download_pocp(self): #Note: downloads from the POCP redspider server appear to be limited to 10000 rows max.
        def POCP_date_parser(datestr):
            d=datestr.replace('/',' ').replace(':',' ').split(' ')
            return datetime(int('20' + d[2]),int(d[1]),int(d[0]),int(d[3]),int(d[4]))

        print 'Getting POCP between ' + self.start_time + ' and ' + self.end_time
        
        bufferIO = StringIO()

        br=mechanize.Browser(factory=mechanize.RobustFactory())
        br.set_handle_refresh(mechanize._http.HTTPRefreshProcessor(), max_time=1) # Follows refresh 0 but not hangs on refresh > 0
        br.addheaders = [('User-agent', 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1')] # User-Agent (this is cheating, ok?)
        r=br.open(cmd_line.pocp_host)
        br.select_form(nr=0)
        br.submit()  #click I agree
        br.select_form(nr=0)     #Now login
        br['email'] = cmd_line.pocp_user
        br['password'] = cmd_line.pocp_pass
        br.submit()  #submit user name and password.
        br.select_form(nr=0)     #select form 
        br['sview'] = ['excel']  #select "excel" although this is in fact a tab delimited table
        br['start'] = self.start_time #set start and end times from above
        br['end'] = self.end_time
        br['planning_status_id[]'] = ['1','2','3'] #['1','2','3']
        response = br.submit()   #submit the search/download for all POCP data between start_time and end_time, save as response
        bufferIO = StringIO()    #Open a string buffer object, write the POCP database to this then read_csv the data...
        bufferIO.write(unicode(response.read())) 
        bufferIO.seek(0)
        current_download = pd.read_csv(bufferIO,parse_dates=['Start','End','Last Modified'],\
                                       date_parser=POCP_date_parser,sep='\t',index_col=0)
        return self.current_download

    def append_pocp(self,pocp):    
        P_all = pd.read_csv(self.cmd_line.pocp_path + 'pocp_all.csv',index_col=0)
        self.P = pd.concat([P_all, self.current_download])   #add latest download 
        self.P['End'] = self.P.End.map(lambda x: p.dt_convert(x)) #convert datetimes.
        self.P['Start'] = self.P.Start.map(lambda x: p.dt_convert(x))
        self.P['Last Modified'] = self.P['Last Modified'].map(lambda x: p.dt_convert(x))
        self.P = self.P.drop_duplicates()    #and drop any duplicates
        self.P.to_csv(self.cmd_line.pocp_path + 'pocp_all.csv') #save the updated POCP database as a csv (good for looking a diffs using gitk)
        return self.P

    def POCP_logic(self,outage_history=False): #this is our main POCP grabber, with addition complex logic to try and get what we want, with a few assumptions thrown in for good measure...
        def POCP_get():
            def get(tdc):
                X=self.P[self.P.Category==tdc]
                Xbool = (X['Start']<=self.end_time) & (X['End']>=self.start_time) #ok, all outages between start and end including those that have been cancelled
                X = X[Xbool]
                X['Duration'] = X.End-X.Start
                if tdc == 'Transmission':
                    del X['MW remaining']
                    del X['MW Loss']
                    del X['MV remaining']
                if tdc == 'Generation':
                    del X['Nature']
                    X['NP_MWh']=X['Duration'].map(lambda x: x/np.timedelta64(1, 's')/3600) * X['MW Loss']
                    X=X.sort(columns=['NP_MWh'],ascending = False)
                del X['Category']
                return X 
            T = get('Transmission')
            G = get('Generation')
            D = get('Direct Connection')
            if outage_history == True:
               if not T.empty:
                   T = T.reset_index().set_index(['id','Last Modified'],drop=False).sortlevel(0)
               if not G.empty:
                   G = G.reset_index().set_index(['id','Last Modified'],drop=False).sort(columns='MW Loss',ascending=False).sortlevel(0)
               if not D.empty:
                   D = D.reset_index().set_index(['id','Last Modified'],drop=False).sortlevel(0)
            elif outage_history == False: #this is what you should see in the current pocp database that is now version controlled.
               if not T.empty:
                   IXT = T.reset_index().groupby('id')['Last Modified'].max() #groupby id, as there will be an entry for each iteration of the outage, then get return the most recent time for that id group,
                   T=T.reset_index().set_index(['id','Last Modified'],drop=False).ix[zip(IXT.to_dict().keys(),IXT.to_dict().values()),:] #then we select the rows, in this case, of a multi-indexed dataframe using the above outage ID and most recent modified time in IX.
               if not G.empty:
                   IXG = G.reset_index().groupby('id')['Last Modified'].max()
                   G=G.reset_index().set_index(['id','Last Modified'],drop=False).ix[zip(IXG.to_dict().keys(),IXG.to_dict().values()),:] #then we select the rows, in this case, of a multi-indexed dataframe using the above outage ID and most recent modified time in IX.
                   G=G.sort(columns='MW Loss',ascending=False)
               if not D.empty:
                   IXD = D.reset_index().groupby('id')['Last Modified'].max() 
                   D=D.reset_index().set_index(['id','Last Modified']).ix[zip(IXD.to_dict().keys(),IXD.to_dict().values()),:] #then we select the rows, in this case, of a multi-indexed dataframe using the above outage ID and most recent modified time in IX.
            return T,G,D
        
        def add_caned_after_start(df):
            caned=df[df['Planning Status']=='Cancelled'] #look at the cancelled entrys
            caned = caned[caned.index.map(lambda x: x[1])>caned.Start.tolist()] #if cancelled after Start time then keep
            confirmed=df[df['Planning Status']=='Confirmed'] #confirmed, and
            tentative=df[df['Planning Status']=='Tentative'] #tentative
            df=confirmed.append(caned) #append confirmed outages with those that have been cancelled after the outage window ended
            #df = df.append(tentative).sort() #also append all tentative outages, then sort.
            df['GIP/GXPs']=df['GIP/GXPs'].map(lambda x: x[0:3])
            df['GIP/GXPs'][df['GIP/GXPs']=='#N/']='NAP'
            df = df.rename(columns={'GIP/GXPs':'GIP'})
            #df = df.dropna(how='any')
            #df['Island'] = df.GIP.map(lambda x: island_map2[x])
            #dfn=df[df['Island']=='North']
            #dfs=df[df['Island']=='South']

            if 'MW Loss' in df.columns:
                df = df[df['MW Loss']>=0]
                df = df.ix[:,['Start','End','MW Loss','Outage Block','GIP','Owner','Nature','Type','Duration','Planning Status']]
            else: 
                df = df.ix[:,['Start','End','Outage Block','GIP','Owner','Nature','Type','Duration','Planning Status']]

            df = df.fillna(0)
            return df

        T,G,D = POCP_get() #get all history
        
        self.G = add_caned_after_start(G)
        self.T = add_caned_after_start(T)
        #self.D = add_caned_after_start(D)

    def today(self,df):
        current_bool = (df['Start']<=datetime.today()) & (df['End']>=(datetime.today())) 
        df = df[current_bool]
        df = df[df['Planning Status'] == 'Confirmed']
        df = df.drop_duplicates()
        df = df.groupby(level=0).tail(1) #return the last modified entry...
        return df

    def now(self,df):
        current_bool = (df['Start']<=datetime.now()) & (df['End']>=(datetime.now())) 
        df = df[current_bool]
        df = df[df['Planning Status'] == 'Confirmed']
        df = df.drop_duplicates()
        df = df.groupby(level=0).tail(1) #return the last modified entry...
        return df

    def timeserializer(self,df):
        def ts(x):
            i = pd.date_range(x['Start'],x['End']-timedelta(minutes=1), freq='30min')
            if 'MW Loss' in x:
                s = pd.Series(float(x['MW Loss']),i)
                return s
        df_ts = df.apply(ts,axis=1).drop_duplicates().sum(axis=0).sort_index()
        return df_ts.ix[self.strt.date():self.endt.date()]

    def main(self):
        outage_history=False
        self.set_date_range() #set the start and end times
        self.download_pocp() #download POCP over the data range
        self.append_pocp(self.current_download) #append current download to the historic POCP data and save.
        self.POCP_logic(outage_history=outage_history)
        self.G = self.mappings(self.G)
        self.Tn = self.now(self.T)
        self.Gn = self.now(self.G)
        self.Tt = self.today(self.T)
        self.Gt = self.today(self.G)

        #self.mappings(self.Gc)  #add generation type and island mappings to outage data

# %%
p=POCP(cmd_line)         #the POCP instance
p.main()
# Out:
# Getting POCP between 07/05/2013 and 07/05/2014

# %%
p.Tn
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
x =p.timeserializer(p.G)

# %%
x.resample('30min','max').plot()

# %%
x.resample('30min','max').plot()
p.timeserializer(p.Gt).plot()

# %%
xt.plot()

# %%
p.G
# Out:
#                                               Start                 End  MW Loss Outage Block  GIP           Owner  Nature        Type            Duration Planning Status Generation type Island
# id          Last Modified
# 1984        2013-09-04 14:07:00 2013-09-02 07:00:00 2013-09-20 17:00:00    108.0        CYD_4  CYD  Contact Energy       0  continuous   18 days, 10:00:00       Confirmed           Hydro     SI
# 2303        2013-08-21 09:33:00 2013-10-04 21:00:00 2013-10-11 17:00:00    350.0        TCC_1  SFD  Contact Energy       0  continuous    6 days, 20:00:00       Tentative         Thermal     NI
# 2338        2013-09-09 11:43:00 2013-07-26 08:00:00 2013-09-24 16:00:00     10.0        TAA_1  TAA  Contact Energy       0  continuous   60 days, 08:00:00       Confirmed      Geothermal     NI
# 2342        2013-09-12 12:41:00 2013-09-11 08:00:00 2013-09-11 21:00:00     51.0        PPI_1  PPI  Contact Energy       0  continuous            13:00:00       Cancelled      Geothermal     NI
# 2344        2013-08-21 09:33:00 2013-09-30 06:00:00 2013-09-30 16:00:00      3.0        OKI_6  OKI  Contact Energy       0  continuous            10:00:00       Tentative      Geothermal     NI
# 2347        2013-05-27 15:30:00 2013-10-09 05:00:00 2013-10-11 18:00:00      7.0       WRK_16  WRK  Contact Energy       0  continuous    2 days, 13:00:00       Confirmed      Geothermal     NI
# 2428        2013-09-04 14:07:00 2013-10-01 07:00:00 2013-10-01 17:30:00    108.0        CYD_1  CYD  Contact Energy       0       daily            10:30:00       Tentative           Hydro     SI
# 2434        2013-08-21 09:33:00 2013-08-27 07:00:00 2013-08-27 17:00:00     35.0        CYD_3  CYD  Contact Energy       0  continuous            10:00:00       Confirmed           Hydro     SI
# 2447        2013-09-04 14:07:00 2013-09-18 07:00:00 2013-09-18 17:00:00     40.0        ROX_2  ROX  Contact Energy       0  continuous            10:00:00       Confirmed           Hydro     SI
# 2462        2013-08-21 09:33:00 2013-09-17 07:00:00 2013-09-17 17:00:00     40.0        ROX_7  ROX  Contact Energy       0  continuous            10:00:00       Confirmed           Hydro     SI
# 2611        2013-09-09 11:43:00 2013-08-06 11:00:00 2013-09-16 17:00:00    100.0       SFD_22  SFD  Contact Energy       0  continuous   41 days, 06:00:00       Confirmed         Thermal     NI
# 2628        2013-07-26 09:23:00 2013-10-17 05:00:00 2013-10-17 21:00:00     14.0      WRK_Stn  WRK  Contact Energy       0  continuous            16:00:00       Tentative      Geothermal     NI
# 2629        2013-09-13 15:13:00 2013-10-02 05:00:00 2013-10-04 18:00:00    200.0      SFD_Stn  SFD  Contact Energy       0  continuous    2 days, 13:00:00       Tentative         Thermal     NI
# 2645        2013-09-04 14:07:00 2013-08-31 11:00:00 2013-08-31 16:00:00    108.0        CYD_1  CYD  Contact Energy       0       daily            05:00:00       Cancelled           Hydro     SI
# 2646        2013-09-04 14:07:00 2013-08-31 11:00:00 2013-08-31 16:00:00    108.0        CYD_2  CYD  Contact Energy       0       daily            05:00:00       Cancelled           Hydro     SI
# 2657        2013-08-22 12:57:00 2013-08-21 11:00:00 2013-08-21 13:00:00     11.0        WRK_7  WRK  Contact Energy       0  continuous            02:00:00       Cancelled      Geothermal     NI
# 2658        2013-09-04 14:07:00 2013-08-28 11:00:00 2013-08-28 13:00:00      7.0       WRK_15  WRK  Contact Energy       0  continuous            02:00:00       Cancelled      Geothermal     NI
# 2659        2013-09-09 11:43:00 2013-09-04 11:00:00 2013-09-04 13:00:00      7.0       WRK_16  WRK  Contact Energy       0  continuous            02:00:00       Cancelled      Geothermal     NI
# 2680        2013-09-12 12:41:00 2013-09-10 05:00:00 2013-09-13 12:00:00      8.0       WRK_10  WRK  Contact Energy       0  continuous    3 days, 07:00:00       Confirmed      Geothermal     NI
# 2687        2013-08-21 09:33:00 2013-08-21 09:00:00 2013-08-23 18:00:00     29.0       WRK_11  WRK  Contact Energy       0  continuous    2 days, 09:00:00       Confirmed      Geothermal     NI
# 2688        2013-08-22 12:57:00 2013-08-26 09:30:00 2013-08-26 11:30:00     52.0        WHI_1  WHI  Contact Energy       0  continuous            02:00:00       Confirmed         Thermal     NI
# 2689        2013-08-22 12:57:00 2013-08-26 13:30:00 2013-08-26 15:30:00     52.0        WHI_2  WHI  Contact Energy       0  continuous            02:00:00       Confirmed         Thermal     NI
# 2690        2013-08-22 12:57:00 2013-08-27 09:30:00 2013-08-27 11:30:00     52.0        WHI_3  WHI  Contact Energy       0  continuous            02:00:00       Confirmed         Thermal     NI
# 2691        2013-09-09 11:43:00 2013-08-23 10:31:00 2013-09-20 23:59:00    350.0        TCC_1  SFD  Contact Energy       0  continuous   28 days, 13:28:00       Cancelled         Thermal     NI
# 2693        2013-09-04 14:07:00 2013-09-16 09:00:00 2013-09-26 18:00:00     11.0        WRK_8  WRK  Contact Energy       0  continuous   10 days, 09:00:00       Confirmed      Geothermal     NI
# 2694        2013-09-04 14:07:00 2013-09-30 08:00:00 2013-10-04 16:00:00      5.0      OKI_Stn  OKI  Contact Energy       0  continuous    4 days, 08:00:00       Tentative      Geothermal     NI
# 2698        2013-09-09 11:43:00 2013-09-04 08:00:00 2013-09-04 17:00:00      4.0      WRK_Stn  WRK  Contact Energy       0  continuous            09:00:00       Cancelled      Geothermal     NI
# 42325       2013-08-08 02:00:00 2013-10-07 06:00:00 2013-10-25 20:00:00    121.5         MAN3  MAN        Meridian       0  continuous   18 days, 14:00:00       Confirmed           Hydro     SI
# 42347       2013-09-14 02:00:00 2013-09-23 06:00:00 2013-09-24 20:00:00    121.5         MAN4  MAN        Meridian       0  continuous    1 days, 14:00:00       Confirmed           Hydro     SI
# 42353       2012-11-30 02:00:00 2013-10-14 06:00:00 2013-10-27 19:00:00    121.5         MAN5  MAN        Meridian       0  continuous   13 days, 13:00:00       Confirmed           Hydro     SI
# 42431       2013-09-03 02:00:00 2013-09-24 06:00:00 2013-09-24 18:00:00     66.0         OHA7  OHA        Meridian       0  continuous            12:00:00       Confirmed           Hydro     SI
# 43211       2013-06-21 11:36:00 2013-09-20 09:00:00 2013-09-20 17:00:00     21.0        ARI_4  ARI    Mighty River       0  continuous            08:00:00       Confirmed           Hydro     NI
# 44180       2013-09-05 23:37:00 2012-11-14 07:00:00 2013-09-04 12:00:00     24.0        ARI_8  ARI    Mighty River       0  continuous  294 days, 05:00:00       Cancelled           Hydro     NI
# 44185       2012-09-29 11:36:00 2013-07-29 07:00:00 2013-10-17 19:00:00     35.2        MTI_9  MTI    Mighty River       0  continuous   80 days, 12:00:00       Confirmed           Hydro     NI
# 44246       2013-08-30 23:36:00 2013-08-29 10:00:00 2013-08-29 16:00:00     32.0        KPO_2  KPO    Mighty River       0  continuous            06:00:00       Cancelled           Hydro     NI
# 44257       2013-08-22 11:36:00 2013-08-22 09:00:00 2013-08-22 17:00:00     32.0        KPO_3  KPO    Mighty River       0  continuous            08:00:00       Cancelled           Hydro     NI
# 44270       2013-08-28 23:37:00 2013-08-27 10:00:00 2013-08-27 16:00:00     18.0        WPA_2  WPA    Mighty River       0  continuous            06:00:00       Cancelled           Hydro     NI
# 44271       2012-11-25 11:36:00 2013-09-25 10:00:00 2013-09-25 16:00:00     18.0        WPA_2  WPA    Mighty River       0  continuous            06:00:00       Confirmed           Hydro     NI
# 44283       2012-11-18 11:35:00 2013-09-18 10:00:00 2013-09-18 16:00:00     18.0        WPA_3  WPA    Mighty River       0  continuous            06:00:00       Confirmed           Hydro     NI
# 44290       2013-06-21 23:36:00 2013-10-10 08:00:00 2013-10-10 16:00:00     26.0        ARA_3  ARA    Mighty River       0  continuous            08:00:00       Confirmed           Hydro     NI
# 44315       2013-08-22 23:37:00 2013-08-21 08:00:00 2013-08-21 17:00:00     26.0        ARA_1  ARA    Mighty River       0  continuous            09:00:00       Cancelled           Hydro     NI
# 44339       2013-09-13 11:36:00 2013-09-19 09:00:00 2013-09-19 17:00:00     26.5        OHK_2  OHK    Mighty River       0  continuous            08:00:00       Confirmed           Hydro     NI
# 44451       2012-11-04 11:36:00 2013-09-04 11:00:00 2013-09-04 16:00:00     26.0        ARI_8  ARI    Mighty River       0  continuous            05:00:00       Confirmed           Hydro     NI
# 44561       2013-06-11 11:36:00 2013-10-10 11:00:00 2013-10-10 17:00:00     21.0        ARI_3  ARI    Mighty River       0  continuous            06:00:00       Confirmed           Hydro     NI
# 45206       2013-09-06 11:36:00 2013-09-21 00:00:00 2013-09-21 18:00:00     45.0        SWN_1  SWN    Mighty River       0  continuous            18:00:00       Confirmed         Thermal     NI
# 45226       2013-09-01 23:38:00 2013-08-31 00:00:00 2013-08-31 18:00:00     45.0        SWN_2  SWN    Mighty River       0  continuous            18:00:00       Cancelled         Thermal     NI
# 45246       2013-08-27 07:52:00 2013-08-24 00:00:00 2013-08-24 18:00:00     50.0        SWN_5  SWN    Mighty River       0  continuous            18:00:00       Cancelled         Thermal     NI
# 45266       2013-09-01 23:38:00 2013-08-31 00:00:00 2013-08-31 18:00:00     20.0        SWN_3  SWN    Mighty River       0  continuous            18:00:00       Cancelled         Thermal     NI
# 45621       2013-07-08 23:37:00 2013-10-18 05:00:00 2013-10-31 15:00:00    140.0        NAP_1  NAP    Mighty River       0  continuous   13 days, 10:00:00       Confirmed      Geothermal     NI
# 45770       2013-06-21 23:36:00 2013-10-14 07:30:00 2013-10-29 19:30:00     26.0        ARA_1  ARA    Mighty River       0  continuous   15 days, 12:00:00       Confirmed           Hydro     NI
# 47565       2012-06-06 16:58:00 2013-09-01 00:00:00 2013-11-24 00:00:00     70.0         RPO5  RPO         Genesis       0  continuous   84 days, 00:00:00       Confirmed           Hydro     NI
# 48176       2013-09-03 11:37:00 2013-09-02 09:00:00 2013-09-02 11:30:00     26.0        ARA_1  ARA    Mighty River       0  continuous            02:30:00       Cancelled           Hydro     NI
# 48178       2013-09-03 23:37:00 2013-09-02 14:00:00 2013-09-02 16:30:00     26.0        ARA_3  ARA    Mighty River       0  continuous            02:30:00       Cancelled           Hydro     NI
# 48200       2012-10-22 11:36:00 2013-08-22 07:30:00 2013-08-22 10:00:00     18.5        ATI_1  ATI    Mighty River       0  continuous            02:30:00       Confirmed           Hydro     NI
# 48201       2012-10-22 11:36:00 2013-08-22 10:00:00 2013-08-22 12:30:00     18.5        ATI_2  ATI    Mighty River       0  continuous            02:30:00       Confirmed           Hydro     NI
# 48202       2012-10-22 23:36:00 2013-08-22 12:30:00 2013-08-22 15:00:00     18.5        ATI_3  ATI    Mighty River       0  continuous            02:30:00       Confirmed           Hydro     NI
# 48203       2012-10-22 23:36:00 2013-08-22 15:00:00 2013-08-22 17:30:00     18.5        ATI_4  ATI    Mighty River       0  continuous            02:30:00       Confirmed           Hydro     NI
# 48216       2013-08-31 11:37:00 2013-08-30 08:00:00 2013-08-30 10:00:00     25.0        WKM_1  WKM    Mighty River       0  continuous            02:00:00       Cancelled      Geothermal     NI
# 48217       2013-08-31 23:38:00 2013-08-30 10:00:00 2013-08-30 12:00:00     25.0        WKM_2  WKM    Mighty River       0  continuous            02:00:00       Cancelled      Geothermal     NI
# 48218       2013-08-31 23:38:00 2013-08-30 12:00:00 2013-08-30 14:00:00     25.0        WKM_3  WKM    Mighty River       0  continuous            02:00:00       Cancelled      Geothermal     NI
# 51474       2013-08-22 23:37:00 2013-08-21 10:00:00 2013-08-21 12:00:00     32.0        KPO_3  KPO    Mighty River       0  continuous            02:00:00       Cancelled           Hydro     NI
# 51487       2013-08-20 23:37:00 2013-08-19 08:00:00 2013-08-19 16:00:00     21.0        ARI_4  ARI    Mighty River       0  continuous            08:00:00       Cancelled           Hydro     NI
# 51510       2013-08-30 23:36:00 2013-08-26 07:30:00 2013-08-29 16:00:00     26.5        OHK_2  OHK    Mighty River       0  continuous    3 days, 08:30:00       Cancelled           Hydro     NI
# 51565       2013-08-08 23:36:00 2013-09-23 08:00:00 2013-09-24 20:00:00     26.0        ARA_2  ARA    Mighty River       0  continuous    1 days, 12:00:00       Confirmed           Hydro     NI
# 51566       2013-08-08 23:36:00 2013-09-25 08:00:00 2013-09-26 20:00:00     26.0        ARA_3  ARA    Mighty River       0  continuous    1 days, 12:00:00       Confirmed           Hydro     NI
# 51573       2013-07-31 07:43:00 2013-10-14 07:30:00 2013-10-18 17:00:00     25.0        WKM_3  WKM    Mighty River       0  continuous    4 days, 09:30:00       Confirmed      Geothermal     NI
# 51575       2013-08-19 23:37:00 2013-08-18 08:00:00 2013-08-18 16:00:00     28.0        ARI_7  ARI    Mighty River       0  continuous            08:00:00       Cancelled           Hydro     NI
# 51600       2013-08-21 23:37:00 2013-08-20 07:00:00 2013-08-20 18:00:00      4.5        RKA_1  WRK    Mighty River       0  continuous            11:00:00       Cancelled      Geothermal     NI
# 51601       2013-08-22 11:36:00 2013-08-22 08:00:00 2013-08-22 12:00:00     26.0        ARA_2  ARA    Mighty River       0  continuous            04:00:00       Cancelled           Hydro     NI
# 51602       2013-09-02 23:37:00 2013-09-01 12:00:00 2013-09-01 18:00:00     25.0        WKM_2  WKM    Mighty River       0  continuous            06:00:00       Cancelled      Geothermal     NI
# 51603       2013-09-02 23:37:00 2013-09-01 12:00:00 2013-09-01 18:00:00     25.0        WKM_4  WKM    Mighty River       0  continuous            06:00:00       Cancelled      Geothermal     NI
# 51610       2013-08-20 11:37:00 2013-08-14 14:48:00 2013-08-19 07:00:00     35.2        MTI_8  MTI    Mighty River       0  continuous    4 days, 16:12:00       Cancelled           Hydro     NI
# 51612       2013-08-20 23:37:00 2013-08-19 11:00:00 2013-08-19 13:00:00     18.5        ATI_1  ATI    Mighty River       0  continuous            02:00:00       Cancelled           Hydro     NI
# 51613       2013-08-20 23:37:00 2013-08-19 13:00:00 2013-08-19 15:00:00     18.5        ATI_3  ATI    Mighty River       0  continuous            02:00:00       Cancelled           Hydro     NI
# 51614       2013-08-20 23:37:00 2013-08-19 15:00:00 2013-08-19 17:00:00     18.5        ATI_4  ATI    Mighty River       0  continuous            02:00:00       Cancelled           Hydro     NI
# 51616       2013-08-22 11:36:00 2013-08-21 10:00:00 2013-08-21 11:00:00     34.0        NAP_1  NAP    Mighty River       0  continuous            01:00:00       Cancelled      Geothermal     NI
# 51617       2013-08-21 11:36:00 2013-08-20 09:00:00 2013-08-20 11:00:00      7.5       MOK_31  WKM    Mighty River       0  continuous            02:00:00       Cancelled      Geothermal     NI
# 51618       2013-08-27 07:52:00 2013-08-20 23:50:00 2013-08-22 13:00:00     18.0        WPA_3  WPA    Mighty River       0  continuous    1 days, 13:10:00       Cancelled           Hydro     NI
# 51620       2013-08-27 07:52:00 2013-08-24 09:00:00 2013-08-24 17:00:00      4.0        ARI_1  ARI    Mighty River       0  continuous            08:00:00       Cancelled           Hydro     NI
# 51621       2013-08-27 07:52:00 2013-08-24 09:00:00 2013-08-24 17:00:00      4.0        ARI_2  ARI    Mighty River       0  continuous            08:00:00       Cancelled           Hydro     NI
# 51622       2013-08-27 07:52:00 2013-08-24 09:00:00 2013-08-24 17:00:00      4.0        ARI_3  ARI    Mighty River       0  continuous            08:00:00       Cancelled           Hydro     NI
# 51623       2013-08-27 07:52:00 2013-08-24 09:00:00 2013-08-24 17:00:00      4.0        ARI_4  ARI    Mighty River       0  continuous            08:00:00       Cancelled           Hydro     NI
# 51624       2013-08-28 07:57:00 2013-08-26 10:00:00 2013-08-26 14:00:00     26.0        ARA_2  ARA    Mighty River       0  continuous            04:00:00       Cancelled           Hydro     NI
# 51627       2013-09-05 23:37:00 2013-09-04 09:00:00 2013-09-04 17:00:00     32.0        KPO_3  KPO    Mighty River       0  continuous            08:00:00       Cancelled           Hydro     NI
# 51628       2013-08-26 23:37:00 2013-08-25 12:30:00 2013-08-25 15:30:00     18.5        ATI_3  ATI    Mighty River       0  continuous            03:00:00       Cancelled           Hydro     NI
# 51634       2013-08-30 23:36:00 2013-08-29 10:00:00 2013-08-29 15:00:00      4.0        ARI_1  ARI    Mighty River       0  continuous            05:00:00       Cancelled           Hydro     NI
# 51636       2013-08-30 23:36:00 2013-08-29 10:00:00 2013-08-29 15:00:00      4.0        ARI_2  ARI    Mighty River       0  continuous            05:00:00       Cancelled           Hydro     NI
# 51638       2013-08-30 23:36:00 2013-08-29 10:00:00 2013-08-29 15:00:00      4.0        ARI_3  ARI    Mighty River       0  continuous            05:00:00       Cancelled           Hydro     NI
# 51640       2013-08-30 23:36:00 2013-08-29 10:00:00 2013-08-29 15:00:00      4.0        ARI_4  ARI    Mighty River       0  continuous            05:00:00       Cancelled           Hydro     NI
# 51644       2013-08-31 11:37:00 2013-08-29 18:16:00 2013-08-30 03:00:00     35.2        MTI_5  MTI    Mighty River       0  continuous            08:44:00       Cancelled           Hydro     NI
# 51646       2013-09-14 23:37:00 2013-09-13 11:00:00 2013-09-13 15:00:00     28.0        ARI_7  ARI    Mighty River       0  continuous            04:00:00       Cancelled           Hydro     NI
# 51648       2013-08-31 23:38:00 2013-08-30 11:50:00 2013-08-30 18:00:00     35.2        MTI_4  MTI    Mighty River       0  continuous            06:10:00       Cancelled           Hydro     NI
# 51649       2013-09-04 23:37:00 2013-09-03 11:00:00 2013-09-03 15:00:00      4.0        ARI_1  ARI    Mighty River       0  continuous            04:00:00       Cancelled           Hydro     NI
# 51650       2013-09-04 23:37:00 2013-09-03 11:00:00 2013-09-03 15:00:00      4.0        ARI_2  ARI    Mighty River       0  continuous            04:00:00       Cancelled           Hydro     NI
# 52959       2013-09-13 14:18:00 2013-09-17 10:00:00 2013-09-17 16:00:00     22.0         PRI4  PRI         Genesis       0  continuous            06:00:00       Confirmed           Hydro     NI
# 53404       2012-11-23 02:00:00 2013-10-05 13:30:00 2013-10-05 16:00:00    164.0          OHA  OHA        Meridian       0  continuous            02:30:00       Confirmed           Hydro     SI
# 54835       2013-08-16 02:00:00 2013-08-19 08:00:00 2013-08-19 16:00:00     55.0         AVI4  AVI        Meridian       0  continuous            08:00:00       Confirmed           Hydro     SI
# 55312       2013-08-13 02:00:00 2013-08-28 08:00:00 2013-08-30 18:00:00     53.0        OHC12  OHC        Meridian       0  continuous    2 days, 10:00:00       Confirmed           Hydro     SI
# 55338       2012-11-16 02:00:00 2013-09-30 08:00:00 2013-10-04 20:00:00    121.5         MAN4  MAN        Meridian       0  continuous    4 days, 12:00:00       Confirmed           Hydro     SI
# 55362       2013-08-07 02:00:00 2013-09-17 08:00:00 2013-09-17 12:00:00     66.0         OHA4  OHA        Meridian       0  continuous            04:00:00       Confirmed           Hydro     SI
# 55363       2013-09-06 02:00:00 2013-09-17 13:00:00 2013-09-17 17:00:00     66.0         OHA5  OHA        Meridian       0  continuous            04:00:00       Confirmed           Hydro     SI
# 55364       2013-09-06 02:00:00 2013-09-18 13:00:00 2013-09-18 17:00:00     66.0         OHA7  OHA        Meridian       0  continuous            04:00:00       Confirmed           Hydro     SI
# 55365       2013-08-07 02:00:00 2013-09-18 08:00:00 2013-09-18 12:00:00     66.0         OHA6  OHA        Meridian       0  continuous            04:00:00       Confirmed           Hydro     SI
# 55386       2013-09-11 02:00:00 2013-09-10 08:00:00 2013-09-10 12:00:00     30.0          TUK  TUK        Meridian       0  continuous            04:00:00       Confirmed            Wind     NI
# 55387       2013-09-11 02:00:00 2013-09-10 12:00:00 2013-09-10 18:00:00     30.0          TUK  TUK        Meridian       0  continuous            06:00:00       Confirmed            Wind     NI
# 55495       2012-11-30 02:00:00 2013-10-07 08:00:00 2013-10-11 20:00:00    121.5         MAN7  MAN        Meridian       0  continuous    4 days, 12:00:00       Confirmed           Hydro     SI
# 55531       2013-07-24 02:00:00 2013-08-12 07:00:00 2013-10-18 16:00:00     15.0         WTK1  WTK        Meridian       0  continuous   67 days, 09:00:00       Confirmed           Hydro     SI
# 56150       2013-08-22 02:00:00 2013-08-26 07:00:00 2013-10-13 19:00:00     90.0         BEN5  BEN        Meridian       0  continuous   48 days, 12:00:00       Confirmed           Hydro     SI
# 56151       2013-08-22 02:00:00 2013-08-26 07:00:00 2013-10-13 18:00:00     90.0         BEN6  BEN        Meridian       0  continuous   48 days, 11:00:00       Confirmed           Hydro     SI
# 56540       2013-08-14 02:00:00 2013-08-18 08:00:00 2013-08-18 17:00:00     53.0        OHC12  OHC        Meridian       0  continuous            09:00:00       Confirmed           Hydro     SI
# 56541       2013-08-14 02:00:00 2013-08-18 08:00:00 2013-08-18 17:00:00     53.0        OHC13  OHC        Meridian       0  continuous            09:00:00       Confirmed           Hydro     SI
# 56542       2013-08-14 02:00:00 2013-08-18 12:30:00 2013-08-18 17:00:00     53.0        OHC14  OHC        Meridian       0  continuous            04:30:00       Confirmed           Hydro     SI
# 56544       2013-08-14 02:00:00 2013-09-09 08:00:00 2013-09-11 18:00:00     90.0         BEN2  BEN        Meridian       0  continuous    2 days, 10:00:00       Confirmed           Hydro     SI
# 56549       2013-08-16 02:00:00 2013-08-19 11:00:00 2013-08-19 13:00:00     90.0         BEN3  BEN        Meridian       0  continuous            02:00:00       Confirmed           Hydro     SI
# 56550       2013-08-16 02:00:00 2013-08-19 11:00:00 2013-08-19 13:00:00     90.0         BEN4  BEN        Meridian       0  continuous            02:00:00       Confirmed           Hydro     SI
# 56567       2013-08-21 02:00:00 2013-08-23 09:00:00 2013-08-23 12:00:00     15.0         WTK2  WTK        Meridian       0  continuous            03:00:00       Confirmed           Hydro     SI
# 56591       2013-09-07 02:00:00 2013-09-10 06:00:00 2013-09-11 20:00:00    121.5         MAN5  MAN        Meridian       0  continuous    1 days, 14:00:00       Confirmed           Hydro     SI
# 56607       2013-08-29 02:00:00 2013-08-29 07:30:00 2013-08-29 08:30:00     15.0         WTK4  WTK        Meridian       0  continuous            01:00:00       Confirmed           Hydro     SI
# 56608       2013-08-29 02:00:00 2013-08-29 11:00:00 2013-08-29 12:00:00     15.0         WTK4  WTK        Meridian       0  continuous            01:00:00       Confirmed           Hydro     SI
# 56610       2013-08-29 02:00:00 2013-08-30 14:00:00 2013-08-30 15:00:00    121.5         MAN4  MAN        Meridian       0  continuous            01:00:00       Confirmed           Hydro     SI
# 56611       2013-08-30 02:00:00 2013-09-24 09:00:00 2013-09-24 17:00:00     34.4          TUK  TUK        Meridian       0  continuous            08:00:00       Confirmed            Wind     NI
# 56639       2013-09-10 02:00:00 2013-09-09 09:00:00 2013-09-09 13:00:00     53.0        OHC13  OHC        Meridian       0  continuous            04:00:00       Confirmed           Hydro     SI
# 56640       2013-09-10 02:00:00 2013-09-09 09:00:00 2013-09-09 13:00:00     53.0        OHC14  OHC        Meridian       0  continuous            04:00:00       Confirmed           Hydro     SI
# 56641       2013-09-10 02:00:00 2013-09-09 09:00:00 2013-09-09 13:00:00     53.0        OHC12  OHC        Meridian       0  continuous            04:00:00       Confirmed           Hydro     SI
# 56642       2013-09-10 02:00:00 2013-09-09 09:00:00 2013-09-09 13:00:00     20.0        OHC15  OHC        Meridian       0  continuous            04:00:00       Confirmed           Hydro     SI
# 56645       2013-09-07 02:00:00 2013-09-23 07:00:00 2013-09-24 17:00:00     55.0         AVI4  AVI        Meridian       0  continuous    1 days, 10:00:00       Confirmed           Hydro     SI
# 56646       2013-09-07 02:00:00 2013-09-07 09:00:00 2013-09-07 10:30:00    121.5         MAN4  MAN        Meridian       0  continuous            01:30:00       Confirmed           Hydro     SI
# 56647       2013-09-07 02:00:00 2013-09-07 10:30:00 2013-09-07 12:00:00    121.5         MAN5  MAN        Meridian       0  continuous            01:30:00       Confirmed           Hydro     SI
# TRUS9239TGA 2013-08-17 05:04:00 2013-09-30 07:00:00 2013-10-12 16:00:00      7.0      TGA_STN  TGA      Trustpower       0  continuous   12 days, 09:00:00       Tentative           Hydro     NI
# TRUS9247BWK 2013-09-05 05:04:00 2013-09-04 07:00:00 2013-09-04 17:00:00     45.0      BWK_STN  BWK      Trustpower       0  continuous            10:00:00       Cancelled           Hydro     SI
# TRUS9248ABY 2013-09-04 05:04:00 2013-09-03 08:50:00 2013-09-04 16:10:00      7.0      ABY_STN  ABY      Trustpower       0  continuous    1 days, 07:20:00       Cancelled           Hydro     SI
# TRUS9251BWK 2013-08-31 05:04:00 2013-08-26 09:00:00 2013-08-30 16:00:00     21.0      BWK_STN  BWK      Trustpower       0  continuous    4 days, 07:00:00       Cancelled           Hydro     SI
# TRUS9252KUM 2013-08-23 12:01:00 2013-08-23 10:30:00 2013-08-23 12:00:00      9.0      KUM_STN  KUM      Trustpower       0  continuous            01:30:00       Cancelled           Hydro     SI
# TRUS9253DOB 2013-08-29 05:04:00 2013-08-28 08:30:00 2013-08-28 12:00:00      1.0      DOB_STN  DOB      Trustpower       0  continuous            03:30:00       Cancelled           Hydro     SI
# TRUS9254DOB 2013-08-29 05:04:00 2013-08-28 12:00:00 2013-08-28 16:30:00      1.0      DOB_STN  DOB      Trustpower       0  continuous            04:30:00       Cancelled           Hydro     SI
# TRUS9255COB 2013-08-23 05:04:00 2013-08-22 08:30:00 2013-08-22 16:00:00     10.0      COB_STN  COB      Trustpower       0  continuous            07:30:00       Cancelled           Hydro     SI
# TRUS9256HUI 2013-08-28 05:04:00 2013-08-27 09:00:00 2013-08-27 17:00:00      1.0      HUI_STN  HUI      Trustpower       0  continuous            08:00:00       Cancelled           Hydro     NI
# TRUS9257HUI 2013-08-29 05:04:00 2013-08-28 09:00:00 2013-08-28 17:00:00      1.0      HUI_STN  HUI      Trustpower       0  continuous            08:00:00       Cancelled           Hydro     NI
# TRUS9258HUI 2013-08-30 05:04:00 2013-08-29 09:00:00 2013-08-29 17:00:00      1.0      HUI_STN  HUI      Trustpower       0  continuous            08:00:00       Cancelled           Hydro     NI
# TRUS9260TGA 2013-08-21 05:04:00 2013-08-20 11:00:00 2013-08-20 16:00:00     15.0      TGA_STN  TGA      Trustpower       0  continuous            05:00:00       Cancelled           Hydro     NI
# TRUS9261KUM 2013-08-21 05:04:00 2013-08-20 10:00:00 2013-08-20 16:00:00      1.0      KUM_STN  KUM      Trustpower       0  continuous            06:00:00       Cancelled           Hydro     SI
# TRUS9265BPE 2013-08-22 05:04:00 2013-08-21 09:30:00 2013-08-21 13:00:00     34.0      BPE_STN  BPE      Trustpower       0  continuous            03:30:00       Cancelled            Wind     NI
# TRUS9266ASB 2013-08-30 05:04:00 2013-08-29 08:00:00 2013-08-29 17:00:00      1.0      ASB_STN  ASB      Trustpower       0  continuous            09:00:00       Cancelled           Hydro     SI
# TRUS9267ASB 2013-09-03 12:01:00 2013-09-02 08:00:00 2013-09-02 17:00:00      1.0      ASB_STN  ASB      Trustpower       0  continuous            09:00:00       Cancelled           Hydro     SI
# TRUS9268ASB 2013-09-05 05:04:00 2013-09-04 08:00:00 2013-09-04 17:00:00      1.0      ASB_STN  ASB      Trustpower       0  continuous            09:00:00       Cancelled           Hydro     SI
# TRUS9269ASB 2013-09-11 05:04:00 2013-09-19 07:30:00 2013-09-19 17:00:00      1.0      ASB_STN  ASB      Trustpower       0  continuous            09:30:00       Tentative           Hydro     SI
# TRUS9270ASB 2013-09-11 05:04:00 2013-09-26 07:30:00 2013-09-26 17:00:00      1.0      ASB_STN  ASB      Trustpower       0  continuous            09:30:00       Tentative           Hydro     SI
# TRUS9271ASB 2013-09-05 05:04:00 2013-09-03 07:30:00 2013-09-03 17:00:00      1.0      ASB_STN  ASB      Trustpower       0  continuous            09:30:00       Cancelled           Hydro     SI
# TRUS9274MAT 2013-09-04 05:04:00 2013-09-03 08:30:00 2013-09-03 10:30:00     40.0      MAT_STN  MAT      Trustpower       0  continuous            02:00:00       Cancelled           Hydro     NI
# TRUS9275MAT 2013-09-04 05:04:00 2013-09-03 11:00:00 2013-09-03 13:30:00     40.0      MAT_STN  MAT      Trustpower       0  continuous            02:30:00       Cancelled           Hydro     NI
# TRUS9278BWK 2013-09-13 05:04:00 2013-09-12 12:30:00 2013-09-12 16:00:00      8.0      BWK_STN  BWK      Trustpower       0  continuous            03:30:00       Cancelled           Hydro     SI
# TRUS9279COL 2013-08-24 05:04:00 2013-08-23 14:00:00 2013-08-23 15:30:00     12.0      COL_STN  COL      Trustpower       0  continuous            01:30:00       Cancelled           Hydro     SI
# TRUS9280ASB 2013-08-24 05:04:00 2013-09-18 08:00:00 2013-09-18 11:30:00     23.0      ASB_STN  ASB      Trustpower       0  continuous            03:30:00       Tentative           Hydro     SI
# TRUS9282CST 2013-08-27 12:01:00 2013-08-27 09:00:00 2013-08-27 17:00:00      1.0      CST_STN  CST      Trustpower       0  continuous            08:00:00       Cancelled           Hydro     NI
# TRUS9285NSY 2013-08-28 05:04:00 2013-08-27 09:00:00 2013-08-27 16:00:00      9.0      NSY_STN  NSY      Trustpower       0  continuous            07:00:00       Cancelled           Hydro     SI
# TRUS9286CST 2013-08-29 05:04:00 2013-08-28 09:00:00 2013-08-28 17:00:00      1.0      CST_STN  CST      Trustpower       0  continuous            08:00:00       Cancelled           Hydro     NI
# TRUS9287CST 2013-08-30 12:01:00 2013-08-29 09:00:00 2013-08-29 17:00:00      1.0      CST_STN  CST      Trustpower       0  continuous            08:00:00       Cancelled           Hydro     NI
# TRUS9289HWB 2013-09-04 05:04:00 2013-09-03 08:30:00 2013-09-03 12:00:00     20.0      HWB_STN  HWB      Trustpower       0  continuous            03:30:00       Cancelled            Wind     SI
# TRUS9290BWK 2013-09-04 05:04:00 2013-09-03 12:30:00 2013-09-03 16:00:00     20.0      BWK_STN  BWK      Trustpower       0  continuous            03:30:00       Cancelled           Hydro     SI
# TRUS9294COL 2013-08-30 05:04:00 2013-08-29 10:00:00 2013-08-29 14:00:00     18.0      COL_STN  COL      Trustpower       0  continuous            04:00:00       Cancelled           Hydro     SI
# TRUS9298BWK 2013-09-05 05:04:00 2013-09-04 09:00:00 2013-09-04 13:00:00     23.0      BWK_STN  BWK      Trustpower       0  continuous            04:00:00       Cancelled           Hydro     SI
# TRUS9299COB 2013-09-05 05:04:00 2013-09-04 08:30:00 2013-09-04 14:00:00      6.0      COB_STN  COB      Trustpower       0  continuous            05:30:00       Cancelled           Hydro     SI
# TRUS9305BWK 2013-09-11 05:04:00 2013-09-10 12:30:00 2013-09-10 16:00:00      7.0      BWK_STN  BWK      Trustpower       0  continuous            03:30:00       Cancelled           Hydro     SI
# TRUS9306CST 2013-09-04 05:04:00 2013-09-03 11:00:00 2013-09-03 16:00:00      1.0      CST_STN  CST      Trustpower       0  continuous            05:00:00       Cancelled           Hydro     NI
# TRUS9307CST 2013-09-05 05:04:00 2013-09-04 10:00:00 2013-09-04 16:00:00      1.0      CST_STN  CST      Trustpower       0  continuous            06:00:00       Cancelled           Hydro     NI
# TRUS9308HUI 2013-09-07 05:04:00 2013-09-19 20:00:00 2013-09-19 20:15:00      5.0      HUI_STN  HUI      Trustpower       0  continuous            00:15:00       Tentative           Hydro     NI
# TRUS9309HUI 2013-09-07 05:04:00 2013-09-21 06:30:00 2013-09-21 06:45:00      5.0      HUI_STN  HUI      Trustpower       0  continuous            00:15:00       Tentative           Hydro     NI
# TRUS9310KUM 2013-09-13 12:01:00 2013-09-12 22:00:00 2013-09-13 05:00:00     10.0      KUM_STN  KUM      Trustpower       0  continuous            07:00:00       Cancelled           Hydro     SI
# TRUS9313ASB 2013-09-11 12:01:00 2013-09-11 11:00:00 2013-09-11 12:30:00     27.0      ASB_STN  ASB      Trustpower       0  continuous            01:30:00       Cancelled           Hydro     SI
# TRUS9315COB 2013-09-12 05:04:00 2013-09-11 11:00:00 2013-09-11 15:00:00     10.0      COB_STN  COB      Trustpower       0  continuous            04:00:00       Cancelled           Hydro     SI
# TRUS9319KUM 2013-09-11 05:04:00 2013-09-17 09:00:00 2013-09-19 16:30:00     10.0      KUM_STN  KUM      Trustpower       0  continuous    2 days, 07:30:00       Tentative           Hydro     SI
# TRUS9321HUI 2013-09-11 05:04:00 2013-09-17 09:15:00 2013-09-18 14:00:00      5.0      HUI_STN  HUI      Trustpower       0  continuous    1 days, 04:45:00       Tentative           Hydro     NI
# TRUS9323ASB 2013-09-13 05:04:00 2013-09-12 07:30:00 2013-09-12 17:00:00      1.0      ASB_STN  ASB      Trustpower       0  continuous            09:30:00       Cancelled           Hydro     SI
# TRUS9324BWK 2013-09-13 05:04:00 2013-09-12 10:30:00 2013-09-12 12:30:00      8.0      BWK_STN  BWK      Trustpower       0  continuous            02:00:00       Cancelled           Hydro     SI
# TRUS9327BWK 2013-09-13 05:04:00 2013-09-16 10:30:00 2013-09-17 17:00:00     20.0      BWK_STN  BWK      Trustpower       0  continuous    1 days, 06:30:00       Tentative           Hydro     SI
# TRUS9330KUM 2013-09-14 05:04:00 2013-09-17 21:35:00 2013-09-18 05:00:00     10.0      KUM_STN  KUM      Trustpower       0  continuous            07:25:00       Tentative           Hydro     SI
# TRUS9331KUM 2013-09-14 05:04:00 2013-09-18 21:35:00 2013-09-19 05:00:00     10.0      KUM_STN  KUM      Trustpower       0  continuous            07:25:00       Tentative           Hydro     SI
# TRUS9332KUM 2013-09-14 05:04:00 2013-09-19 21:35:00 2013-09-20 05:00:00     10.0      KUM_STN  KUM      Trustpower       0  continuous            07:25:00       Tentative           Hydro     SI
# TRUS9333ASB 2013-09-14 05:04:00 2013-09-19 11:00:00 2013-09-19 12:30:00     27.0      ASB_STN  ASB      Trustpower       0  continuous            01:30:00       Tentative           Hydro     SI

# %%
test = p.Gn.apply(ts,axis=1)

# %%
test.T.ix['2013/7/1':'2013/12/1'].T.drop_duplicates().sum(axis=0).sort_index().plot()

# %%
test.drop_duplicates().sum(axis=0).sort_index().plot()

# %%
p.Gn = p.Gn.reset_index(level=1)
p.Gn.reset_index().set_index(['Island','Generation type','GIP']).sort()['MW Loss'].groupby(level=[0,1,2]).sum().unstack(level=2).sum(axis=1)#.to_html('current_gen_outages.html')
# Out:
# Island  Generation type
# NI      Geothermal          33.0
#         Hydro              299.6
#         Thermal            328.0
# SI      Hydro              476.0
# dtype: float64

# %%
p.Tn.sort(columns='Duration',ascending=False).apply(p.ts,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-a7fc2dacb97a> in <module>()
# ----> 1 p.Tn.sort(columns='Duration',ascending=False).apply(p.ts,axis=1)
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.12.0_167_gb2845a1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, args, **kwds)
#    4400                     return self._apply_raw(f, axis)
#    4401                 else:
# -> 4402                     return self._apply_standard(f, axis)
#    4403             else:
#    4404                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python2.7/dist-packages/pandas-0.12.0_167_gb2845a1-py2.7-linux-x86_64.egg/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures)
#    4475                     # no k defined yet
#    4476                     pass
# -> 4477                 raise e
#    4478
#    4479
#
# KeyError: ('MW Loss', u'occurred at index (2705100, 2013-07-10 18:23:00)')

# %%
p.G.reset_index().set_index(['Island','Generation type','Owner']).sort()
# Out:
#                                                           id       Last Modified               Start                 End  MW Loss      Outage Block  GIP  Nature        Type            Duration Planning Status
# Island Generation type Owner
# NaN    NaN             Contact Energy                   2621 2013-06-27 15:29:00 2014-02-01 00:01:00 2014-02-23 23:59:00      0.0           MAU_Stn  n/a       0  continuous   22 days, 23:58:00       Confirmed
# NI     Geothermal      Contact Energy                   1937 2013-04-18 10:17:00 2013-04-15 05:00:00 2013-04-17 18:00:00      8.0            WRK_16  WRK       0  continuous    2 days, 13:00:00       Cancelled
#                        Contact Energy                   1951 2013-05-27 15:30:00 2013-05-22 08:00:00 2013-05-23 16:00:00     51.0             PPI_1  PPI       0  continuous    1 days, 08:00:00       Cancelled
#                        Contact Energy                   2219 2013-05-20 08:37:00 2013-05-14 10:00:00 2013-05-14 16:00:00      8.0            WRK_16  WRK       0  continuous            06:00:00       Cancelled
#                        Contact Energy                   2221 2013-06-10 16:15:00 2013-06-05 10:00:00 2013-06-05 16:00:00      8.0            WRK_15  WRK       0  continuous            06:00:00       Cancelled
#                        Contact Energy                   2278 2013-03-25 10:12:00 2013-03-20 10:00:00 2013-03-20 14:00:00     36.0             OKI_2  OKI       0  continuous            04:00:00       Cancelled
#                        Contact Energy                   2304 2013-03-25 10:12:00 2013-03-21 10:00:00 2013-03-21 18:00:00      6.0             WRK_7  WRK       0  continuous            08:00:00       Cancelled
#                        Contact Energy                   2306 2013-04-24 18:05:00 2013-04-15 06:00:00 2013-04-19 16:00:00    110.0           WRK_Stn  WRK       0  continuous    4 days, 10:00:00       Cancelled
#                        Contact Energy                   2337 2013-03-25 10:12:00 2013-03-23 04:00:00 2013-03-23 15:00:00     25.0            WRK_11  WRK       0  continuous            11:00:00       Cancelled
#                        Contact Energy                   2338 2013-09-09 11:43:00 2013-07-26 08:00:00 2013-09-24 16:00:00     10.0             TAA_1  TAA       0  continuous   60 days, 08:00:00       Confirmed
#                        Contact Energy                   2340 2013-07-15 08:43:00 2013-07-10 05:00:00 2013-07-12 18:00:00      6.0            WRK_15  WRK       0  continuous    2 days, 13:00:00       Cancelled
#                        Contact Energy                   2342 2013-09-12 12:41:00 2013-09-11 08:00:00 2013-09-11 21:00:00     51.0             PPI_1  PPI       0  continuous            13:00:00       Cancelled
#                        Contact Energy                   2344 2013-08-21 09:33:00 2013-09-30 06:00:00 2013-09-30 16:00:00      3.0             OKI_6  OKI       0  continuous            10:00:00       Tentative
#                        Contact Energy                   2347 2013-05-27 15:30:00 2013-10-09 05:00:00 2013-10-11 18:00:00      7.0            WRK_16  WRK       0  continuous    2 days, 13:00:00       Confirmed
#                        Contact Energy                   2354 2013-05-27 15:30:00 2014-01-26 03:00:00 2014-01-26 23:59:00      4.0            WRK_15  WRK       0  continuous            20:59:00       Confirmed
#                        Contact Energy                   2355 2013-05-27 15:30:00 2014-02-08 08:00:00 2014-02-08 18:00:00     51.0             PPI_1  PPI       0  continuous            10:00:00       Confirmed
#                        Contact Energy                   2401 2013-08-05 16:37:00 2013-08-03 05:30:00 2013-08-03 19:30:00     13.0           WRK_Stn  WRK       0  continuous            14:00:00       Cancelled
#                        Contact Energy                   2402 2013-07-31 09:39:00 2013-07-30 04:00:00 2013-07-30 21:00:00     43.0           WRK_Stn  WRK       0  continuous            17:00:00       Cancelled
#                        Contact Energy                   2419 2013-05-01 11:37:00 2013-04-30 10:00:00 2013-04-30 12:00:00      4.0           WRK_Stn  WRK       0  continuous            02:00:00       Cancelled
#                        Contact Energy                   2479 2013-05-27 15:30:00 2013-05-23 06:00:00 2013-05-23 20:00:00     12.0           WRK_Stn  WRK       0  continuous            14:00:00       Cancelled
#                        Contact Energy                   2480 2013-05-02 17:05:00 2013-05-28 06:00:00 2013-05-28 20:00:00     55.0           WRK_Stn  WRK       0  continuous            14:00:00       Confirmed
#                        Contact Energy                   2481 2013-05-02 17:05:00 2013-05-30 06:00:00 2013-05-30 20:00:00     55.0           WRK_Stn  WRK       0  continuous            14:00:00       Confirmed
#                        Contact Energy                   2540 2013-05-05 12:51:00 2013-05-03 12:00:00 2013-05-03 18:00:00     14.0            WRK_12  WRK       0  continuous            06:00:00       Cancelled
#                        Contact Energy                   2560 2013-06-12 10:04:00 2013-06-11 06:00:00 2013-06-11 23:59:00     28.0           WRK_Stn  WRK       0  continuous            17:59:00       Cancelled
#                        Contact Energy                   2575 2013-07-22 16:24:00 2013-07-18 10:00:00 2013-07-18 15:00:00      6.0             WRK_7  WRK       0  continuous            05:00:00       Cancelled
#                        Contact Energy                   2576 2013-07-29 14:47:00 2013-07-15 04:00:00 2013-07-27 16:00:00     10.0             WRK_1  WRK       0  continuous   12 days, 12:00:00       Cancelled
#                        Contact Energy                   2577 2013-08-07 10:42:00 2013-08-06 08:00:00 2013-08-06 18:00:00     11.0             WRK_8  WRK       0  continuous            10:00:00       Cancelled
#                        Contact Energy                   2584 2013-06-14 08:33:00 2013-06-13 04:30:00 2013-06-13 21:00:00      3.0             OKI_6  OKI       0  continuous            16:30:00       Cancelled
#                        Contact Energy                   2600 2013-06-24 11:06:00 2013-06-18 06:00:00 2013-06-20 09:00:00     54.0           WRK_Stn  WRK       0  continuous    2 days, 03:00:00       Cancelled
#                        Contact Energy                   2613 2013-07-17 12:41:00 2013-07-16 10:00:00 2013-07-16 17:00:00      8.0            WRK_16  WRK       0  continuous            07:00:00       Cancelled
#                        Contact Energy                   2617 2013-07-18 10:17:00 2013-07-15 04:00:00 2013-07-17 21:00:00     18.0           WRK_Stn  WRK       0  continuous    2 days, 17:00:00       Cancelled
#                        Contact Energy                   2620 2013-08-05 16:37:00 2013-08-02 04:00:00 2013-08-02 21:00:00     28.0           WRK_Stn  WRK       0  continuous            17:00:00       Cancelled
#                        Contact Energy                   2622 2013-07-18 10:17:00 2013-07-17 10:00:00 2013-07-17 16:00:00     20.0           WRK_Stn  WRK       0  continuous            06:00:00       Cancelled
#                        Contact Energy                   2628 2013-09-04 14:07:00 2013-10-30 05:00:00 2013-10-30 21:00:00     45.0           WRK_Stn  WRK       0  continuous            16:00:00       Tentative
#                        Contact Energy                   2641 2013-07-22 16:24:00 2013-07-22 08:00:00 2013-07-26 16:00:00      3.0             PPI_1  PPI       0  continuous    4 days, 08:00:00       Cancelled
#                        Contact Energy                   2642 2013-07-22 16:24:00 2013-07-16 21:40:00 2013-07-19 22:00:00     11.0             WRK_9  WRK       0  continuous    3 days, 00:20:00       Cancelled
#                        Contact Energy                   2643 2013-08-05 16:37:00 2013-08-01 10:00:00 2013-08-01 15:00:00     11.0             WRK_1  WRK       0  continuous            05:00:00       Cancelled
#                        Contact Energy                   2644 2013-08-05 16:37:00 2013-07-29 08:00:00 2013-07-31 16:00:00     14.0           WRK_Stn  WRK       0  continuous    2 days, 08:00:00       Cancelled
#                        Contact Energy                   2652 2013-08-08 15:34:00 2013-08-05 08:00:00 2013-08-12 14:00:00     12.0           TAA_Stn  TAA       0  continuous    7 days, 06:00:00       Tentative
#                        Contact Energy                   2657 2013-08-22 12:57:00 2013-08-21 11:00:00 2013-08-21 13:00:00     11.0             WRK_7  WRK       0  continuous            02:00:00       Cancelled
#                        Contact Energy                   2658 2013-09-04 14:07:00 2013-08-28 11:00:00 2013-08-28 13:00:00      7.0            WRK_15  WRK       0  continuous            02:00:00       Cancelled
#                        Contact Energy                   2659 2013-09-09 11:43:00 2013-09-04 11:00:00 2013-09-04 13:00:00      7.0            WRK_16  WRK       0  continuous            02:00:00       Cancelled
#                        Contact Energy                   2680 2013-09-12 12:41:00 2013-09-10 05:00:00 2013-09-13 12:00:00      8.0            WRK_10  WRK       0  continuous    3 days, 07:00:00       Confirmed
#                        Contact Energy                   2687 2013-08-21 09:33:00 2013-08-21 09:00:00 2013-08-23 18:00:00     29.0            WRK_11  WRK       0  continuous    2 days, 09:00:00       Confirmed
#                        Contact Energy                   2693 2013-09-04 14:07:00 2013-09-16 09:00:00 2013-09-26 18:00:00     11.0             WRK_8  WRK       0  continuous   10 days, 09:00:00       Confirmed
#                        Contact Energy                   2694 2013-09-04 14:07:00 2013-09-30 08:00:00 2013-10-04 16:00:00      5.0           OKI_Stn  OKI       0  continuous    4 days, 08:00:00       Tentative
#                        Contact Energy                   2698 2013-09-09 11:43:00 2013-09-04 08:00:00 2013-09-04 17:00:00      4.0           WRK_Stn  WRK       0  continuous            09:00:00       Cancelled
#                        Contact Energy                   2700 2013-09-09 11:43:00 2013-09-05 14:00:00 2013-09-05 15:00:00     12.0           TAA_Stn  TAA       0  continuous            01:00:00       Cancelled
#                        Contact Energy                   2705 2013-09-04 14:07:00 2013-09-11 08:00:00 2013-09-20 16:00:00     12.0             TAA_2  TAA       0  continuous    9 days, 08:00:00       Confirmed
#                        Contact Energy                   2718 2013-09-13 15:13:00 2013-09-22 04:00:00 2013-09-22 21:00:00     59.0           WRK_Stn  WRK       0  continuous            17:00:00       Confirmed
#                        Mighty River                    44190 2013-08-19 11:36:00 2013-12-09 06:00:00 2013-12-13 06:00:00    100.0             KAG_1  KAW       0  continuous    4 days, 00:00:00       Confirmed
#                        Mighty River                    44714 2013-07-01 23:36:00 2013-06-25 06:00:00 2013-06-30 18:00:00     25.0             WKM_4  WKM       0  continuous    5 days, 12:00:00       Cancelled
#                        Mighty River                    44715 2013-08-29 11:36:00 2013-08-29 09:00:00 2013-08-29 17:00:00     25.0             WKM_4  WKM       0  continuous            08:00:00       Cancelled
#                        Mighty River                    44717 2013-08-07 11:36:00 2013-11-18 07:00:00 2013-12-07 19:00:00     25.0             WKM_4  WKM       0  continuous   19 days, 12:00:00       Confirmed
#                        Mighty River                    44763 2013-05-04 23:37:00 2013-05-01 07:00:00 2013-05-03 19:00:00     25.0             WKM_1  WKM       0  continuous    2 days, 12:00:00       Cancelled
#                        Mighty River                    44764 2013-07-27 23:36:00 2013-07-26 08:00:00 2013-07-26 16:00:00     25.0             WKM_1  WKM       0  continuous            08:00:00       Cancelled
#                        Mighty River                    44765 2013-05-30 11:36:00 2013-11-07 08:00:00 2013-11-07 16:00:00     25.0             WKM_1  WKM       0  continuous            08:00:00       Confirmed
#                        Mighty River                    45141 2013-07-05 23:36:00 2013-06-25 06:00:00 2013-07-04 18:00:00     19.4            MOK_30  WKM       0  continuous    9 days, 12:00:00       Cancelled
#                        Mighty River                    45147 2013-03-31 02:05:00 2013-03-05 06:00:00 2013-03-29 18:00:00      7.5            MOK_31  WKM       0  continuous   24 days, 12:00:00       Cancelled
#                        Mighty River                    45148 2013-04-17 11:36:00 2014-02-17 06:00:00 2014-02-21 18:00:00      7.5            MOK_31  WKM       0  continuous    4 days, 12:00:00       Confirmed
#                        Mighty River                    45153 2013-07-05 23:36:00 2013-06-25 06:00:00 2013-07-04 18:00:00      7.5            MOK_32  WKM       0  continuous    9 days, 12:00:00       Cancelled
#                        Mighty River                    45154 2013-04-24 11:36:00 2014-02-24 06:00:00 2014-03-09 18:00:00      7.5            MOK_32  WKM       0  continuous   13 days, 12:00:00       Confirmed
#                        Mighty River                    45159 2013-07-05 23:36:00 2013-06-25 06:00:00 2013-07-04 18:00:00      7.5            MOK_41  WKM       0  continuous    9 days, 12:00:00       Cancelled
#                        Mighty River                    45621 2013-07-08 23:37:00 2013-10-18 05:00:00 2013-10-31 15:00:00    140.0             NAP_1  NAP       0  continuous   13 days, 10:00:00       Confirmed
#                        Mighty River                    45725 2013-04-10 11:36:00 2014-02-10 07:00:00 2014-04-11 19:00:00     25.0             WKM_1  WKM       0  continuous   60 days, 12:00:00       Confirmed
#                        Mighty River                    48216 2013-08-31 11:37:00 2013-08-30 08:00:00 2013-08-30 10:00:00     25.0             WKM_1  WKM       0  continuous            02:00:00       Cancelled
#                        Mighty River                    48217 2013-08-31 23:38:00 2013-08-30 10:00:00 2013-08-30 12:00:00     25.0             WKM_2  WKM       0  continuous            02:00:00       Cancelled
#                        Mighty River                    48218 2013-08-31 23:38:00 2013-08-30 12:00:00 2013-08-30 14:00:00     25.0             WKM_3  WKM       0  continuous            02:00:00       Cancelled
#                        Mighty River                    48219 2013-08-31 23:38:00 2013-08-30 14:00:00 2013-08-30 17:00:00     25.0             WKM_4  WKM       0  continuous            03:00:00       Cancelled
#                        Mighty River                    48431 2013-05-30 11:36:00 2013-11-08 11:00:00 2013-11-08 13:30:00     25.0             WKM_1  WKM       0  continuous            02:30:00       Confirmed
#                        Mighty River                    48605 2013-08-07 11:36:00 2013-12-09 07:00:00 2013-12-18 19:00:00     25.0             WKM_2  WKM       0  continuous    9 days, 12:00:00       Confirmed
#                        Mighty River                    48990 2013-03-23 23:36:00 2013-01-14 05:30:00 2013-03-22 15:00:00     25.0             WKM_2  WKM       0  continuous   67 days, 09:30:00       Cancelled
#                        Mighty River                    48993 2013-09-07 23:36:00 2013-09-01 08:00:00 2013-09-06 16:00:00     25.0             WKM_3  WKM       0  continuous    5 days, 08:00:00       Cancelled
#                        Mighty River                    49843 2013-04-12 23:37:00 2013-04-10 07:00:00 2013-04-11 18:00:00     25.0             WKM_3  WKM       0  continuous    1 days, 11:00:00       Cancelled
#                        Mighty River                    50134 2013-01-07 11:36:00 2013-01-01 00:00:00 2013-06-30 12:00:00     10.0             KAG_1  KAW       0  continuous  180 days, 12:00:00       Cancelled
#                        Mighty River                    50725 2013-07-01 23:37:00 2013-06-25 06:00:00 2013-06-30 16:00:00     25.0             WKM_1  WKM       0  continuous    5 days, 10:00:00       Cancelled
#                        Mighty River                    50727 2013-07-01 23:37:00 2013-06-25 06:00:00 2013-06-30 16:00:00     25.0             WKM_2  WKM       0  continuous    5 days, 10:00:00       Cancelled
#                        Mighty River                    51024 2013-04-07 23:37:00 2013-04-02 06:00:00 2013-04-06 18:00:00      4.5            RKA_12  WRK       0  continuous    4 days, 12:00:00       Cancelled
#                        Mighty River                    51047 2013-06-18 23:37:00 2013-06-15 05:00:00 2013-06-17 14:00:00    100.0             KAG_1  KAW       0  continuous    2 days, 09:00:00       Cancelled
#                        Mighty River                    51051 2013-07-01 23:37:00 2013-06-25 06:00:00 2013-06-30 16:00:00     25.0             WKM_3  WKM       0  continuous    5 days, 10:00:00       Cancelled
#                        Mighty River                    51052 2013-07-05 23:36:00 2013-06-25 06:00:00 2013-07-04 18:00:00      7.5            MOK_31  WKM       0  continuous    9 days, 12:00:00       Cancelled
#                        Mighty River                    51057 2013-03-22 23:37:00 2013-03-21 10:00:00 2013-03-21 13:00:00     34.0             NAP_1  NAP       0  continuous            03:00:00       Cancelled
#                        Mighty River                    51065 2013-03-26 23:36:00 2013-03-24 07:00:00 2013-03-25 18:00:00     25.0             WKM_4  WKM       0  continuous    1 days, 11:00:00       Cancelled
#                        Mighty River                    51072 2013-03-25 23:37:00 2013-03-24 07:00:00 2013-03-24 19:00:00     25.0             WKM_3  WKM       0  continuous            12:00:00       Cancelled
#                        Mighty River                    51091 2013-03-26 23:36:00 2013-03-25 13:30:00 2013-03-25 14:30:00     25.0             WKM_2  WKM       0  continuous            01:00:00       Cancelled
#                        Mighty River                    51092 2013-04-09 23:36:00 2013-04-08 07:30:00 2013-04-08 13:00:00      4.5            MOK_11  WKM       0  continuous            05:30:00       Cancelled
#                        Mighty River                    51093 2013-04-09 23:36:00 2013-04-08 13:30:00 2013-04-08 19:00:00      4.5            MOK_12  WKM       0  continuous            05:30:00       Cancelled
#                        Mighty River                    51094 2013-04-10 23:37:00 2013-04-09 06:30:00 2013-04-09 12:00:00      4.5            MOK_21  WKM       0  continuous            05:30:00       Cancelled
#                        Mighty River                    51095 2013-04-10 23:37:00 2013-04-09 12:30:00 2013-04-09 18:00:00      4.5            MOK_22  WKM       0  continuous            05:30:00       Cancelled
#                        Mighty River                    51096 2013-04-11 23:37:00 2013-04-10 06:30:00 2013-04-10 16:00:00      4.5             MOK_1  WKM       0  continuous            09:30:00       Cancelled
#                        Mighty River                    51097 2013-04-12 23:37:00 2013-04-11 06:30:00 2013-04-11 17:00:00      7.5            MOK_31  WKM       0  continuous            10:30:00       Cancelled
#                        Mighty River                    51098 2013-04-13 23:37:00 2013-04-12 06:30:00 2013-04-12 17:00:00      7.5            MOK_32  WKM       0  continuous            10:30:00       Cancelled
#                        Mighty River                    51102 2013-04-04 23:37:00 2013-04-03 10:00:00 2013-04-03 12:00:00     34.0             NAP_1  NAP       0  continuous            02:00:00       Cancelled
#                        Mighty River                    51110 2013-04-24 23:37:00 2013-04-22 06:30:00 2013-04-23 16:00:00      4.5            MOK_21  WKM       0  continuous    1 days, 09:30:00       Cancelled
#                        Mighty River                    51149 2013-04-19 11:37:00 2013-04-18 10:00:00 2013-04-18 11:30:00     34.0             NAP_1  NAP       0  continuous            01:30:00       Cancelled
#                        Mighty River                    51151 2013-04-20 23:37:00 2013-04-19 08:00:00 2013-04-19 16:00:00      4.5             RKA_1  WRK       0  continuous            08:00:00       Cancelled
#                        Mighty River                    51172 2013-04-23 23:37:00 2013-04-22 07:30:00 2013-04-22 15:00:00     21.0             KAG_1  KAW       0  continuous            07:30:00       Cancelled
#                        Mighty River                    51173 2013-04-23 23:37:00 2013-04-22 13:00:00 2013-04-22 17:00:00     25.0             WKM_4  WKM       0  continuous            04:00:00       Cancelled
#                        Mighty River                    51174 2013-04-24 23:37:00 2013-04-23 08:00:00 2013-04-23 13:00:00      4.5             RKA_1  WRK       0  continuous            05:00:00       Cancelled
#                        Mighty River                    51182 2013-04-28 23:37:00 2013-04-27 11:00:00 2013-04-27 17:30:00     21.0             KAG_1  KAW       0  continuous            06:30:00       Cancelled
#                        Mighty River                    51183 2013-05-11 23:37:00 2013-05-10 06:00:00 2013-05-10 16:00:00      4.5             RKA_1  WRK       0  continuous            10:00:00       Cancelled
#                        Mighty River                    51184 2013-05-11 23:37:00 2013-05-10 06:00:00 2013-05-10 16:00:00     15.0            RKA_10  WRK       0  continuous            10:00:00       Cancelled
#                        Mighty River                    51185 2013-05-11 23:37:00 2013-05-10 06:00:00 2013-05-10 16:00:00      4.5            RKA_11  WRK       0  continuous            10:00:00       Cancelled
#                        Mighty River                    51186 2013-05-11 23:37:00 2013-05-10 06:00:00 2013-05-10 16:00:00      4.5            RKA_12  WRK       0  continuous            10:00:00       Cancelled
#                        Mighty River                    51187 2013-05-11 23:37:00 2013-05-10 06:00:00 2013-05-10 18:00:00      6.0            RKA_21  WRK       0  continuous            12:00:00       Cancelled
#                        Mighty River                    51188 2013-05-02 11:37:00 2013-05-01 10:00:00 2013-05-01 11:30:00     34.0             NAP_1  NAP       0  continuous            01:30:00       Cancelled
#                        Mighty River                    51190 2013-05-02 23:37:00 2013-05-01 08:00:00 2013-05-01 14:00:00      4.5            RKA_12  WRK       0  continuous            06:00:00       Cancelled
#                        Mighty River                    51191 2013-05-03 23:37:00 2013-05-02 08:00:00 2013-05-02 14:00:00      4.5            RKA_11  WRK       0  continuous            06:00:00       Cancelled
#                        Mighty River                    51197 2013-05-06 23:37:00 2013-05-04 14:00:00 2013-05-05 16:30:00     21.0             KAG_1  KAW       0  continuous    1 days, 02:30:00       Cancelled
#                        Mighty River                    51198 2013-05-07 23:37:00 2013-05-06 07:30:00 2013-05-06 16:30:00     22.0             KAG_1  KAW       0  continuous            09:00:00       Cancelled
#                        Mighty River                    51211 2013-05-04 23:37:00 2013-05-03 07:00:00 2013-05-03 17:00:00      5.0             KAG_1  KAW       0  continuous            10:00:00       Cancelled
#                        Mighty River                    51225 2013-05-15 23:37:00 2013-05-14 08:00:00 2013-05-14 14:00:00      6.0            RKA_21  WRK       0  continuous            06:00:00       Cancelled
#                        Mighty River                    51226 2013-05-23 23:36:00 2013-05-22 08:00:00 2013-05-22 15:00:00     15.0            RKA_10  WRK       0  continuous            07:00:00       Cancelled
#                        Mighty River                    51240 2013-05-11 23:37:00 2013-05-10 07:00:00 2013-05-10 17:00:00      4.0             KAG_1  KAW       0  continuous            10:00:00       Cancelled
#                        Mighty River                    51241 2013-05-13 23:37:00 2013-05-11 14:00:00 2013-05-12 20:00:00     22.0             KAG_1  KAW       0  continuous    1 days, 06:00:00       Cancelled
#                        Mighty River                    51242 2013-05-16 11:37:00 2013-05-15 10:00:00 2013-05-15 11:30:00     34.0             NAP_1  NAP       0  continuous            01:30:00       Cancelled
#                        Mighty River                    51243 2013-05-18 23:37:00 2013-05-13 06:30:00 2013-05-17 16:00:00      4.5             MOK_2  WKM       0  continuous    4 days, 09:30:00       Cancelled
#                        Mighty River                    51255 2013-06-06 23:37:00 2013-05-13 21:05:00 2013-06-05 12:00:00     25.0             WKM_4  WKM       0  continuous   22 days, 14:55:00       Cancelled
#                        Mighty River                    51287 2013-05-25 11:37:00 2013-05-24 06:00:00 2013-05-24 10:30:00      9.0           RKA_STN  WRK       0  continuous            04:30:00       Cancelled
#                        Mighty River                    51297 2013-06-01 18:16:00 2013-05-30 08:00:00 2013-05-30 14:00:00      4.5             RKA_1  WRK       0  continuous            06:00:00       Cancelled
#                        Mighty River                    51298 2013-06-06 11:37:00 2013-06-05 10:00:00 2013-06-05 11:00:00     34.0             NAP_1  NAP       0  continuous            01:00:00       Cancelled
#                        Mighty River                    51319 2013-06-06 23:37:00 2013-06-05 06:30:00 2013-06-05 17:00:00      4.5            MOK_22  WKM       0  continuous            10:30:00       Cancelled
#                        Mighty River                    51325 2013-06-07 11:37:00 2013-06-05 12:00:00 2013-06-06 00:00:00     12.5             WKM_4  WKM       0  continuous            12:00:00       Cancelled
#                        Mighty River                    51330 2013-06-08 23:37:00 2013-06-07 10:00:00 2013-06-07 14:00:00     25.0             WKM_4  WKM       0  continuous            04:00:00       Cancelled
#                        Mighty River                    51362 2013-06-19 23:37:00 2013-06-18 10:00:00 2013-06-18 15:00:00     34.0             NAP_1  NAP       0  continuous            05:00:00       Cancelled
#                        Mighty River                    51404 2013-07-26 23:36:00 2013-07-25 09:00:00 2013-07-25 17:00:00     25.0             WKM_3  WKM       0  continuous            08:00:00       Cancelled
#                        Mighty River                    51405 2013-06-18 23:36:00 2013-10-24 09:00:00 2013-10-24 17:00:00     25.0             WKM_3  WKM       0  continuous            08:00:00       Confirmed
#                        Mighty River                    51406 2013-08-29 23:36:00 2014-03-07 11:00:00 2014-03-07 12:00:00     25.0             WKM_4  WKM       0  continuous            01:00:00       Confirmed
#                        Mighty River                    51459 2013-07-11 11:37:00 2013-07-10 10:00:00 2013-07-10 11:00:00     34.0             NAP_1  NAP       0  continuous            01:00:00       Cancelled
#                        Mighty River                    51507 2013-07-19 23:37:00 2013-07-18 13:00:00 2013-07-18 15:00:00     25.0             WKM_1  WKM       0  continuous            02:00:00       Cancelled
#                        Mighty River                    51509 2013-07-29 23:37:00 2013-07-26 07:30:00 2013-07-28 16:00:00     30.0             KAG_1  KAW       0  continuous    2 days, 08:30:00       Cancelled
#                        Mighty River                    51516 2013-07-25 11:37:00 2013-07-24 10:00:00 2013-07-24 11:00:00     34.0             NAP_1  NAP       0  continuous            01:00:00       Cancelled
#                        Mighty River                    51556 2013-07-27 23:37:00 2013-07-26 06:00:00 2013-07-26 14:30:00      7.8             MOK_3  WKM       0  continuous            08:30:00       Cancelled
#                        Mighty River                    51557 2013-07-27 23:37:00 2013-07-26 06:00:00 2013-07-26 14:30:00      7.5            MOK_31  WKM       0  continuous            08:30:00       Cancelled
#                        Mighty River                    51558 2013-07-27 23:37:00 2013-07-26 06:00:00 2013-07-26 14:30:00      7.5            MOK_32  WKM       0  continuous            08:30:00       Cancelled
#                        Mighty River                    51559 2013-07-27 23:37:00 2013-07-26 06:00:00 2013-07-26 13:00:00      6.5            MOK_41  WKM       0  continuous            07:00:00       Cancelled
#                        Mighty River                    51571 2013-08-10 23:37:00 2013-08-05 07:00:00 2013-08-09 16:00:00      6.0            RKA_21  WRK       0  continuous    4 days, 09:00:00       Cancelled
#                        Mighty River                    51573 2013-07-31 07:43:00 2013-10-14 07:30:00 2013-10-18 17:00:00     25.0             WKM_3  WKM       0  continuous    4 days, 09:30:00       Confirmed
#                        Mighty River                    51576 2013-08-08 11:37:00 2013-08-07 10:00:00 2013-08-07 11:00:00     34.0             NAP_1  NAP       0  continuous            01:00:00       Cancelled
#                        Mighty River                    51578 2013-08-09 23:37:00 2013-08-08 13:00:00 2013-08-08 15:00:00     25.0             WKM_1  WKM       0  continuous            02:00:00       Cancelled
#                        Mighty River                    51588 2013-08-13 23:36:00 2013-08-11 23:00:00 2013-08-12 16:00:00     14.0             KAG_1  KAW       0  continuous            17:00:00       Cancelled
#                        Mighty River                    51599 2013-08-13 23:36:00 2013-08-12 10:00:00 2013-08-12 12:00:00      4.5            RKA_11  WRK       0  continuous            02:00:00       Cancelled
#                        Mighty River                    51600 2013-08-21 23:37:00 2013-08-20 07:00:00 2013-08-20 18:00:00      4.5             RKA_1  WRK       0  continuous            11:00:00       Cancelled
#                        Mighty River                    51602 2013-09-02 23:37:00 2013-09-01 12:00:00 2013-09-01 18:00:00     25.0             WKM_2  WKM       0  continuous            06:00:00       Cancelled
#                        Mighty River                    51603 2013-09-02 23:37:00 2013-09-01 12:00:00 2013-09-01 18:00:00     25.0             WKM_4  WKM       0  continuous            06:00:00       Cancelled
#                        Mighty River                    51616 2013-08-22 11:36:00 2013-08-21 10:00:00 2013-08-21 11:00:00     34.0             NAP_1  NAP       0  continuous            01:00:00       Cancelled
#                        Mighty River                    51617 2013-08-21 11:36:00 2013-08-20 09:00:00 2013-08-20 11:00:00      7.5            MOK_31  WKM       0  continuous            02:00:00       Cancelled
#                        Mighty River                    51659 2013-09-05 23:37:00 2013-09-04 13:00:00 2013-09-04 14:00:00     34.0             NAP_1  NAP       0  continuous            01:00:00       Cancelled
#                        Mighty River                    51681 2013-09-08 23:37:00 2013-09-07 13:57:00 2013-09-07 15:30:00     25.0             WKM_3  WKM       0  continuous            01:33:00       Cancelled
#                        Mighty River                    51682 2013-09-11 08:46:00 2013-09-23 06:00:00 2013-09-23 18:00:00      4.5             RKA_1  WRK       0  continuous            12:00:00       Confirmed
#                        Mighty River                    51683 2013-09-11 08:46:00 2013-09-23 06:00:00 2013-09-23 15:00:00     15.0            RKA_10  WRK       0  continuous            09:00:00       Confirmed
#                        Mighty River                    51684 2013-09-11 08:46:00 2013-09-23 06:00:00 2013-09-23 15:00:00      4.5            RKA_11  WRK       0  continuous            09:00:00       Confirmed
#                        Mighty River                    51685 2013-09-11 08:46:00 2013-09-23 06:00:00 2013-09-23 15:00:00      4.5            RKA_12  WRK       0  continuous            09:00:00       Confirmed
#                        Mighty River                    51686 2013-09-11 08:46:00 2013-09-23 06:00:00 2013-09-23 15:00:00      6.0            RKA_21  WRK       0  continuous            09:00:00       Confirmed
#                        Top Energy      November Plant Outage 2013-07-29 15:10:00 2013-11-05 12:00:00 2013-11-09 12:00:00     24.0  OEC 1 OEC 2 OEC3  KOE       0  continuous    4 days, 00:00:00       Tentative
#                        Top Energy                 OEC 2  Nov 2013-07-29 15:11:00 2013-11-09 12:00:00 2013-11-12 12:00:00      9.0       OEC 1 OEC 2  KOE       0  continuous    3 days, 00:00:00       Tentative
#                        Top Energy                   OEC 2 CC 2013-07-29 15:11:00 2013-09-04 08:00:00 2013-09-04 12:00:00      4.5             OEC 2  KOE       0       daily            04:00:00       Tentative
#                        Top Energy                  OEC 3 Nov 2013-07-29 15:11:00 2013-11-03 12:00:00 2013-11-05 12:00:00     14.0             OEC 3  KOE       0  continuous    2 days, 00:00:00       Tentative
#                        Top Energy                    OEC1 CC 2013-07-29 15:11:00 2013-08-27 08:00:00 2013-08-27 12:00:00      4.5             OEC 1  KOE       0       daily            04:00:00       Tentative
#                        Trustpower                TRUS8835WRK 2013-04-05 05:04:00 2013-04-03 13:00:00 2013-04-04 16:00:00      1.0           WRK_STN  WRK       0  continuous    1 days, 03:00:00       Cancelled
#                        Trustpower                TRUS9040WRK 2013-06-07 05:04:00 2013-06-06 08:30:00 2013-06-06 12:30:00      1.0           WRK_STN  WRK       0  continuous            04:00:00       Cancelled
#                        Trustpower                TRUS9041WRK 2013-06-08 05:04:00 2013-06-07 08:30:00 2013-06-07 16:00:00      1.0           WRK_STN  WRK       0  continuous            07:30:00       Cancelled
#                        Trustpower                TRUS9223WRK 2013-08-16 05:04:00 2013-08-15 09:30:00 2013-08-15 16:00:00      2.0           WRK_STN  WRK       0  continuous            06:30:00       Cancelled
#        Hydro           Genesis                         47563 2013-07-23 10:57:00 2013-06-17 08:00:00 2013-07-16 20:00:00     22.0              PRI4  TUI       0  continuous   29 days, 12:00:00       Cancelled
#                        Genesis                         51358 2013-04-04 14:02:00 2013-03-28 09:00:00 2013-03-28 15:00:00     70.0              RPO6  RPO       0  continuous            06:00:00       Cancelled
#                        Genesis                         51479 2013-04-04 14:02:00 2013-03-27 19:30:00 2013-03-28 01:00:00     22.0              PRI5  PRI       0  continuous            05:30:00       Cancelled
#                        Genesis                         51498 2013-04-10 16:27:00 2013-04-02 19:00:00 2013-04-03 00:00:00     22.0              PRI4  PRI       0  continuous            05:00:00       Cancelled
#                        Genesis                         51598 2013-04-16 14:17:00 2013-04-08 19:00:00 2013-04-09 01:30:00     22.0              PRI4  PRI       0  continuous            06:30:00       Cancelled
#                        Genesis                         51658 2013-04-20 14:18:00 2013-04-13 08:00:00 2013-04-13 14:00:00    240.0           TKU_STN  TKU       0  continuous            06:00:00       Cancelled
#                        Genesis                         51678 2013-04-27 16:14:00 2013-04-20 07:00:00 2013-04-20 19:00:00     22.0              PRI4  PRI       0  continuous            12:00:00       Cancelled
#                        Genesis                         51719 2013-04-29 14:17:00 2013-04-22 13:00:00 2013-04-22 15:00:00     36.0           KTW_STN  KTW       0  continuous            02:00:00       Cancelled
#                        Genesis                         51738 2013-05-02 14:18:00 2013-04-25 13:00:00 2013-04-25 17:00:00     22.0              PRI4  PRI       0  continuous            04:00:00       Cancelled
# ...
#                        Trustpower                TRUS9110ASB 2013-07-17 05:04:00 2013-07-16 08:00:00 2013-07-16 17:00:00      2.0           ASB_STN  ASB       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9111BWK 2013-07-03 05:04:00 2013-07-02 12:30:00 2013-07-02 16:00:00      8.0           BWK_STN  BWK       0  continuous            03:30:00       Cancelled
#                        Trustpower                TRUS9112BWK 2013-07-10 05:04:00 2013-07-09 12:30:00 2013-07-09 16:00:00      7.0           BWK_STN  BWK       0  continuous            03:30:00       Cancelled
#                        Trustpower                TRUS9123BWK 2013-07-04 05:04:00 2013-07-03 08:00:00 2013-07-03 16:00:00     20.0           BWK_STN  BWK       0  continuous            08:00:00       Cancelled
#                        Trustpower                TRUS9124ARG 2013-07-05 05:04:00 2013-07-03 08:00:00 2013-07-04 16:00:00     11.0           ARG_STN  ARG       0  continuous    1 days, 08:00:00       Cancelled
#                        Trustpower                TRUS9127COL 2013-07-05 05:04:00 2013-07-04 10:30:00 2013-07-04 13:30:00     12.0           COL_STN  COL       0  continuous            03:00:00       Cancelled
#                        Trustpower                TRUS9131ARG 2013-07-06 12:01:00 2013-07-05 08:00:00 2013-07-05 17:00:00     11.0           ARG_STN  ARG       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9132ARG 2013-07-09 05:04:00 2013-07-08 08:00:00 2013-07-08 17:00:00     11.0           ARG_STN  ARG       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9133ARG 2013-07-11 05:04:00 2013-07-10 08:00:00 2013-07-10 17:00:00      7.0           ARG_STN  ARG       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9134ARG 2013-07-12 05:04:00 2013-07-11 08:00:00 2013-07-11 17:00:00     11.0           ARG_STN  ARG       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9136ASB 2013-07-31 05:04:00 2013-07-30 08:00:00 2013-07-30 16:30:00     27.0           ASB_STN  ASB       0  continuous            08:30:00       Cancelled
#                        Trustpower                TRUS9137BWK 2013-07-24 05:04:00 2013-07-23 12:30:00 2013-07-23 16:00:00     20.0           BWK_STN  BWK       0  continuous            03:30:00       Cancelled
#                        Trustpower                TRUS9138ARG 2013-07-10 05:04:00 2013-07-09 08:00:00 2013-07-09 17:00:00      3.0           ARG_STN  ARG       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9143COB 2013-07-25 05:04:00 2013-07-24 08:30:00 2013-07-24 16:00:00      3.0           COB_STN  COB       0  continuous            07:30:00       Cancelled
#                        Trustpower                TRUS9144COB 2013-07-31 05:04:00 2013-07-30 08:30:00 2013-07-30 14:00:00     10.0           COB_STN  COB       0  continuous            05:30:00       Cancelled
#                        Trustpower                TRUS9147COL 2013-07-26 05:06:00 2013-07-24 08:00:00 2013-07-25 15:00:00     12.0           COL_STN  COL       0  continuous    1 days, 07:00:00       Cancelled
#                        Trustpower                TRUS9149ARG 2013-07-20 05:04:00 2013-07-19 10:30:00 2013-07-19 11:30:00     11.0           ARG_STN  ARG       0  continuous            01:00:00       Cancelled
#                        Trustpower                TRUS9157DOB 2013-08-01 12:01:00 2013-07-31 09:00:00 2013-07-31 15:00:00      3.0           DOB_STN  DOB       0  continuous            06:00:00       Cancelled
#                        Trustpower                TRUS9158HKK 2013-08-02 05:04:00 2013-08-01 09:00:00 2013-08-01 16:30:00      3.0           HKK_STN  HKK       0  continuous            07:30:00       Cancelled
#                        Trustpower                TRUS9159BWK 2013-07-26 05:06:00 2013-07-22 08:30:00 2013-07-25 16:00:00     17.0           BWK_STN  BWK       0  continuous    3 days, 07:30:00       Cancelled
#                        Trustpower                TRUS9160BWK 2013-08-02 12:01:00 2013-07-29 08:00:00 2013-08-06 16:00:00     25.0           BWK_STN  BWK       0  continuous    8 days, 08:00:00       Cancelled
#                        Trustpower                TRUS9164ARG 2013-08-17 05:04:00 2013-08-12 12:00:00 2013-08-16 18:00:00     11.0           ARG_STN  ARG       0  continuous    4 days, 06:00:00       Cancelled
#                        Trustpower                TRUS9200ASB 2013-08-02 05:04:00 2013-08-01 08:00:00 2013-08-01 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9201ASB 2013-08-07 05:04:00 2013-08-06 08:00:00 2013-08-06 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9202ASB 2013-08-14 05:02:00 2013-08-13 08:00:00 2013-08-13 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9203ASB 2013-08-21 05:04:00 2013-08-20 08:00:00 2013-08-20 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9205HKK 2013-08-03 05:04:00 2013-08-02 10:00:00 2013-08-02 12:00:00      3.0           HKK_STN  HKK       0  continuous            02:00:00       Cancelled
#                        Trustpower                TRUS9212COL 2013-08-22 05:04:00 2013-08-07 08:00:00 2013-08-28 16:30:00     12.0           COL_STN  COL       0  continuous   21 days, 08:30:00       Cancelled
#                        Trustpower                TRUS9213BWK 2013-08-10 05:04:00 2013-08-07 08:30:00 2013-08-08 16:00:00     20.0           BWK_STN  BWK       0  continuous    1 days, 07:30:00       Cancelled
#                        Trustpower                TRUS9214COL 2013-08-07 05:04:00 2013-08-06 10:00:00 2013-08-06 14:00:00     12.0           COL_STN  COL       0  continuous            04:00:00       Cancelled
#                        Trustpower                TRUS9215ABY 2013-08-08 05:04:00 2013-08-07 08:00:00 2013-08-07 16:00:00      7.0           ABY_STN  ABY       0  continuous            08:00:00       Cancelled
#                        Trustpower                TRUS9218HKK 2013-08-15 05:00:00 2013-08-14 09:30:00 2013-08-14 12:30:00      3.0           HKK_STN  HKK       0  continuous            03:00:00       Cancelled
#                        Trustpower                TRUS9221NSY 2013-08-22 05:04:00 2013-08-19 08:30:00 2013-08-23 15:00:00     16.0           NSY_STN  NSY       0  continuous    4 days, 06:30:00       Cancelled
#                        Trustpower                TRUS9225BWK 2013-08-12 05:04:00 2013-08-09 21:35:00 2013-08-13 12:00:00     20.0           BWK_STN  BWK       0  continuous    3 days, 14:25:00       Cancelled
#                        Trustpower                TRUS9247BWK 2013-09-05 05:04:00 2013-09-04 07:00:00 2013-09-04 17:00:00     45.0           BWK_STN  BWK       0  continuous            10:00:00       Cancelled
#                        Trustpower                TRUS9248ABY 2013-09-04 05:04:00 2013-09-03 08:50:00 2013-09-04 16:10:00      7.0           ABY_STN  ABY       0  continuous    1 days, 07:20:00       Cancelled
#                        Trustpower                TRUS9251BWK 2013-08-31 05:04:00 2013-08-26 09:00:00 2013-08-30 16:00:00     21.0           BWK_STN  BWK       0  continuous    4 days, 07:00:00       Cancelled
#                        Trustpower                TRUS9252KUM 2013-08-23 12:01:00 2013-08-23 10:30:00 2013-08-23 12:00:00      9.0           KUM_STN  KUM       0  continuous            01:30:00       Cancelled
#                        Trustpower                TRUS9253DOB 2013-08-29 05:04:00 2013-08-28 08:30:00 2013-08-28 12:00:00      1.0           DOB_STN  DOB       0  continuous            03:30:00       Cancelled
#                        Trustpower                TRUS9254DOB 2013-08-29 05:04:00 2013-08-28 12:00:00 2013-08-28 16:30:00      1.0           DOB_STN  DOB       0  continuous            04:30:00       Cancelled
#                        Trustpower                TRUS9255COB 2013-08-23 05:04:00 2013-08-22 08:30:00 2013-08-22 16:00:00     10.0           COB_STN  COB       0  continuous            07:30:00       Cancelled
#                        Trustpower                TRUS9261KUM 2013-08-21 05:04:00 2013-08-20 10:00:00 2013-08-20 16:00:00      1.0           KUM_STN  KUM       0  continuous            06:00:00       Cancelled
#                        Trustpower                TRUS9266ASB 2013-08-30 05:04:00 2013-08-29 08:00:00 2013-08-29 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9267ASB 2013-09-03 12:01:00 2013-09-02 08:00:00 2013-09-02 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9268ASB 2013-09-05 05:04:00 2013-09-04 08:00:00 2013-09-04 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:00:00       Cancelled
#                        Trustpower                TRUS9269ASB 2013-09-11 05:04:00 2013-09-19 07:30:00 2013-09-19 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:30:00       Tentative
#                        Trustpower                TRUS9270ASB 2013-09-11 05:04:00 2013-09-26 07:30:00 2013-09-26 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:30:00       Tentative
#                        Trustpower                TRUS9271ASB 2013-09-05 05:04:00 2013-09-03 07:30:00 2013-09-03 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:30:00       Cancelled
#                        Trustpower                TRUS9278BWK 2013-09-13 05:04:00 2013-09-12 12:30:00 2013-09-12 16:00:00      8.0           BWK_STN  BWK       0  continuous            03:30:00       Cancelled
#                        Trustpower                TRUS9279COL 2013-08-24 05:04:00 2013-08-23 14:00:00 2013-08-23 15:30:00     12.0           COL_STN  COL       0  continuous            01:30:00       Cancelled
#                        Trustpower                TRUS9280ASB 2013-08-24 05:04:00 2013-09-18 08:00:00 2013-09-18 11:30:00     23.0           ASB_STN  ASB       0  continuous            03:30:00       Tentative
#                        Trustpower                TRUS9285NSY 2013-08-28 05:04:00 2013-08-27 09:00:00 2013-08-27 16:00:00      9.0           NSY_STN  NSY       0  continuous            07:00:00       Cancelled
#                        Trustpower                TRUS9290BWK 2013-09-04 05:04:00 2013-09-03 12:30:00 2013-09-03 16:00:00     20.0           BWK_STN  BWK       0  continuous            03:30:00       Cancelled
#                        Trustpower                TRUS9294COL 2013-08-30 05:04:00 2013-08-29 10:00:00 2013-08-29 14:00:00     18.0           COL_STN  COL       0  continuous            04:00:00       Cancelled
#                        Trustpower                TRUS9298BWK 2013-09-05 05:04:00 2013-09-04 09:00:00 2013-09-04 13:00:00     23.0           BWK_STN  BWK       0  continuous            04:00:00       Cancelled
#                        Trustpower                TRUS9299COB 2013-09-05 05:04:00 2013-09-04 08:30:00 2013-09-04 14:00:00      6.0           COB_STN  COB       0  continuous            05:30:00       Cancelled
#                        Trustpower                TRUS9305BWK 2013-09-11 05:04:00 2013-09-10 12:30:00 2013-09-10 16:00:00      7.0           BWK_STN  BWK       0  continuous            03:30:00       Cancelled
#                        Trustpower                TRUS9310KUM 2013-09-13 12:01:00 2013-09-12 22:00:00 2013-09-13 05:00:00     10.0           KUM_STN  KUM       0  continuous            07:00:00       Cancelled
#                        Trustpower                TRUS9313ASB 2013-09-11 12:01:00 2013-09-11 11:00:00 2013-09-11 12:30:00     27.0           ASB_STN  ASB       0  continuous            01:30:00       Cancelled
#                        Trustpower                TRUS9315COB 2013-09-12 05:04:00 2013-09-11 11:00:00 2013-09-11 15:00:00     10.0           COB_STN  COB       0  continuous            04:00:00       Cancelled
#                        Trustpower                TRUS9319KUM 2013-09-11 05:04:00 2013-09-17 09:00:00 2013-09-19 16:30:00     10.0           KUM_STN  KUM       0  continuous    2 days, 07:30:00       Tentative
#                        Trustpower                TRUS9323ASB 2013-09-13 05:04:00 2013-09-12 07:30:00 2013-09-12 17:00:00      1.0           ASB_STN  ASB       0  continuous            09:30:00       Cancelled
#                        Trustpower                TRUS9324BWK 2013-09-13 05:04:00 2013-09-12 10:30:00 2013-09-12 12:30:00      8.0           BWK_STN  BWK       0  continuous            02:00:00       Cancelled
#                        Trustpower                TRUS9327BWK 2013-09-13 05:04:00 2013-09-16 10:30:00 2013-09-17 17:00:00     20.0           BWK_STN  BWK       0  continuous    1 days, 06:30:00       Tentative
#                        Trustpower                TRUS9330KUM 2013-09-14 05:04:00 2013-09-17 21:35:00 2013-09-18 05:00:00     10.0           KUM_STN  KUM       0  continuous            07:25:00       Tentative
#                        Trustpower                TRUS9331KUM 2013-09-14 05:04:00 2013-09-18 21:35:00 2013-09-19 05:00:00     10.0           KUM_STN  KUM       0  continuous            07:25:00       Tentative
#                        Trustpower                TRUS9332KUM 2013-09-14 05:04:00 2013-09-19 21:35:00 2013-09-20 05:00:00     10.0           KUM_STN  KUM       0  continuous            07:25:00       Tentative
#                        Trustpower                TRUS9333ASB 2013-09-14 05:04:00 2013-09-19 11:00:00 2013-09-19 12:30:00     27.0           ASB_STN  ASB       0  continuous            01:30:00       Tentative
#        Wind            Meridian                        56005 2013-04-30 02:00:00 2013-05-07 10:00:00 2013-05-07 15:00:00     58.0               WHL  WHL       0  continuous            05:00:00       Confirmed
#                        Trustpower                TRUS8800HWB 2013-03-22 05:03:00 2013-03-21 12:30:00 2013-03-21 16:00:00      8.0           HWB_STN  HWB       0  continuous            03:30:00       Cancelled
#                        Trustpower                TRUS8842HWB 2013-04-19 05:04:00 2013-04-18 12:30:00 2013-04-18 15:00:00     20.0           HWB_STN  HWB       0  continuous            02:30:00       Cancelled
#                        Trustpower                TRUS8952HWB 2013-05-14 12:01:00 2013-05-14 09:00:00 2013-05-14 15:00:00     10.0           HWB_STN  HWB       0  continuous            06:00:00       Cancelled
#                        Trustpower                TRUS8956HWB 2013-05-24 05:04:00 2013-05-23 10:00:00 2013-05-23 14:00:00      6.0           HWB_STN  HWB       0  continuous            04:00:00       Cancelled
#                        Trustpower                TRUS9005HWB 2013-06-07 12:01:00 2013-06-05 10:00:00 2013-06-05 16:00:00     10.0           HWB_STN  HWB       0  continuous            06:00:00       Cancelled
#                        Trustpower                TRUS9142HWB 2013-07-25 05:04:00 2013-07-24 12:30:00 2013-07-24 16:00:00      5.0           HWB_STN  HWB       0  continuous            03:30:00       Cancelled
#                        Trustpower                TRUS9289HWB 2013-09-04 05:04:00 2013-09-03 08:30:00 2013-09-03 12:00:00     20.0           HWB_STN  HWB       0  continuous            03:30:00       Cancelled

# %%
x = p.POCP_to_timeseries(p.G)

# %%
x.T.sum(level=[0,1]).T.to_csv('test_ts.csv')

# %%
temp=T.groupby(level=0).tail(1)

# %%
#temp.index = pd.MultiIndex.from_tuples(temp.index)

# %%
temp
# Out:
#                                           id Assessment                 End GIP/GXPs       Last Modified Nature      Outage Block       Owner Planning Status               Start        Type            Duration
# id      id      Last Modified
# 1000045 1000045 2013-08-31 06:23:00  1000045        New 2013-09-30 18:00:00      HAY 2013-08-31 06:23:00     RS           HAY_F_1  Transpower       Confirmed 2013-05-23 14:00:00  continuous  130 days, 04:00:00
# 1000281 1000281 2013-09-10 06:23:00  1000281        New 2013-11-04 06:59:00      STK 2013-09-10 06:23:00    OPE       STK_CB_2248  Transpower       Confirmed 2013-07-31 17:00:00  continuous   95 days, 13:59:00
# 1000298 1000298 2013-08-01 06:23:00  1000298        New 2013-12-26 18:00:00      CBG 2013-08-01 06:23:00     RS          CBG_11RB  Transpower       Confirmed 2013-04-19 12:34:00  continuous  251 days, 05:26:00
# 1000837 1000837 2013-07-23 11:23:00  1000837        New 2013-10-28 18:00:00      PEN 2013-07-23 11:23:00     RS        PEN_CB_828  Transpower       Confirmed 2013-09-15 22:00:00  continuous   42 days, 20:00:00
# 1000871 1000871 2013-07-24 06:23:00  1000871        New 2013-09-23 18:00:00      BLN 2013-07-24 06:23:00     RS           BLN_C_4  Transpower       Confirmed 2013-06-23 09:31:00       daily   92 days, 08:29:00
# 1001047 1001047 2013-07-04 11:23:00  1001047        New 2013-10-16 18:00:00      PAK 2013-07-04 11:23:00     RS        PAK_CB_482  Transpower       Confirmed 2013-07-16 07:00:00  continuous   92 days, 11:00:00
# 1001048 1001048 2013-07-04 11:23:00  1001048        New 2013-10-16 18:00:00      PAK 2013-07-04 11:23:00     RS        PAK_CB_472  Transpower       Confirmed 2013-07-16 07:00:00  continuous   92 days, 11:00:00
# 1001300 1001300 2013-08-30 11:23:00  1001300        New 2013-09-30 16:00:00      MLG 2013-08-30 11:23:00     RS         MLG_FDR_7  Transpower       Confirmed 2013-07-12 23:00:00  continuous   79 days, 17:00:00
# 1001586 1001586 2013-07-26 09:23:00  1001586        New 2013-09-22 18:00:00      BOB 2013-07-26 09:23:00     RS         BOB_HAM_2  Transpower       Confirmed 2013-09-16 07:00:00  continuous    6 days, 11:00:00
# 1001679 1001679 2013-08-22 10:23:00  1001679        New 2013-09-17 15:00:00      WKM 2013-08-22 10:23:00    SCA         WKM_RTU_1  Transpower       Confirmed 2013-09-16 08:30:00       daily    1 days, 06:30:00
# 1001688 1001688 2013-09-14 06:23:00  1001688        New 2013-09-18 17:30:00      ALB 2013-09-14 06:23:00     RS         ALB_WRD_4  Transpower       Confirmed 2013-09-09 07:30:00  continuous    9 days, 10:00:00
# 1001689 1001689 2013-09-14 06:23:00  1001689        New 2013-09-18 17:30:00      WRD 2013-09-14 06:23:00     RS       WRD_220BS_A  Transpower       Confirmed 2013-09-09 07:30:00  continuous    9 days, 10:00:00
# 1001690 1001690 2013-09-14 06:23:00  1001690        New 2013-09-18 17:30:00      WRD 2013-09-14 06:23:00     RS            WRD_T7  Transpower       Confirmed 2013-09-09 07:30:00  continuous    9 days, 10:00:00
# 2785321 2785321 2013-05-30 12:23:00  2785321        New 2013-09-20 15:00:00      OTA 2013-05-30 12:23:00     RS         HLY_OTA_2  Transpower       Confirmed 2013-09-16 08:00:00       daily    4 days, 07:00:00
# 2785322 2785322 2013-05-30 12:23:00  2785322        New 2013-09-20 15:00:00      TAK 2013-05-30 12:23:00     RS            TAK_T8  Transpower       Confirmed 2013-09-16 08:00:00       daily    4 days, 07:00:00
# 2786969 2786969 2013-08-17 06:23:00  2786969        New 2013-09-16 18:00:00      STK 2013-08-17 06:23:00     RS      STK_FDR_2162  Transpower       Confirmed 2013-05-21 20:31:00  continuous  117 days, 21:29:00
# 2787657 2787657 2013-08-01 06:23:00  2787657        New 2013-11-01 18:00:00      OWH 2013-08-01 06:23:00     RS        OWH_11BS_A  Transpower       Confirmed 2013-06-08 22:00:00  continuous  145 days, 20:00:00

# %%
p=POCP(cmd_line)         #the POCP instance
p.set_date_range()       #set a date range to download
data = p.download_pocp() #get data over this date range
P = p.append_pocp(data)  #append this data to the historic POCP data and save.
P['End'] = P.End.map(lambda x: p.dt_convert(x))
P['Start'] = P.Start.map(lambda x: p.dt_convert(x))
P['Last Modified'] = P['Last Modified'].map(lambda x: p.dt_convert(x))


#start=datetime.now()-timedelta(days=0.5*366) 
#end=datetime.now()+timedelta(days=0.5*366)
# Out:
# Getting POCP between 17/03/2013 and 17/03/2014

# %%
p.POCP_logic(P,start,end,outage_history=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7d8eb530db34> in <module>()
# ----> 1 p.POCP_logic(P,start,end,outage_history=True)
#
# NameError: name 'start' is not defined

# %%
P.tail()
# Out:
#         Assessment      Category                 End GIP/GXPs       Last Modified  MV remaining  MW Loss  MW remaining Nature     Outage Block         Owner Planning Status               Start        Type
# id
# 2784087        New  Transmission 2014-03-28 18:00:00      ISL 2013-05-30 12:23:00           NaN      NaN           NaN     RS      ISL_220BS_D    Transpower       Confirmed 2014-03-17 07:30:00  continuous
# 2784095        New  Transmission 2014-03-28 18:00:00      ISL 2013-05-30 12:23:00           NaN      NaN           NaN     RS         ISL_C_21    Transpower       Confirmed 2014-03-17 07:30:00  continuous
# 2784876        New  Transmission 2014-03-17 18:00:00      EDG 2013-07-10 18:23:00           NaN      NaN           NaN     RS      EDG_FDR_162    Transpower       Confirmed 2014-03-17 07:30:00       daily
# 2783642        New  Transmission 2014-03-17 18:00:00  TMH,CCT 2013-05-30 12:23:00           NaN      NaN           NaN     RS  CCT_768_RRD_TMH    Transpower       Confirmed 2014-03-17 09:30:00       daily
# 44479          New    Generation 2014-03-17 13:30:00      ARI 2012-05-22 12:14:00             0       26             0    NaN            ARI_7  Mighty River       Cancelled 2014-03-17 12:30:00  continuous

# %%
p.Tc
# Out:
#                                           Start                 End      Outage Block  GIP       Owner Nature        Type            Duration Planning Status
# id      Last Modified
# 1000045 2013-08-31 06:23:00 2013-05-23 14:00:00 2013-09-30 18:00:00           HAY_F_1  HAY  Transpower     RS  continuous  130 days, 04:00:00       Confirmed
# 1002374 2013-09-04 11:23:00 2013-09-16 08:00:00 2013-09-16 16:00:00  CCT_1030_EDG_TMI  CCT  Transpower     RS       daily            08:00:00       Confirmed
# 1002656 2013-09-05 15:23:00 2013-09-16 08:00:00 2013-09-20 17:00:00        GFD_FDR_21  GFD  Transpower     RS  continuous    4 days, 09:00:00       Confirmed
# 1002695 2013-09-13 06:23:00 2013-09-12 07:30:00 2013-09-16 18:30:00            GOR_T2  GOR  Transpower     RS       daily    4 days, 11:00:00       Confirmed
# 1003527 2013-09-10 12:23:00 2013-09-13 08:00:00 2013-09-25 20:00:00      GLN_FDR_2572  GLN  Transpower     RS  continuous   12 days, 12:00:00       Confirmed
# 1003751 2013-09-14 06:23:00 2013-09-16 08:00:00 2013-09-27 18:00:00        HAY_CB_962  HAY  Transpower     RS  continuous   11 days, 10:00:00       Confirmed
# 1003766 2013-09-16 06:23:00 2013-09-16 08:00:00 2013-09-16 18:00:00            BOB_T3  BOB  Transpower     RS       daily            10:00:00       Confirmed
# 1003767 2013-09-16 06:23:00 2013-09-16 08:00:00 2013-09-16 18:00:00    BOB_87_107_127  BOB  Transpower     RS       daily            10:00:00       Confirmed
# 2705100 2013-07-10 18:23:00 2010-06-30 18:01:00 2013-11-30 17:30:00          ISL_SC_4  ISL  Transpower     RS  continuous 1248 days, 23:29:00       Confirmed
# 2776541 2013-07-10 18:23:00 2013-02-11 11:30:00 2013-12-24 18:00:00           HAY_T17  HAY  Transpower    OPE  continuous  316 days, 06:30:00       Confirmed
# 2778569 2013-09-11 06:23:00 2013-05-24 13:30:00 2013-10-18 18:00:00        WRD_CB_182  WRD  Transpower     RS  continuous  147 days, 04:30:00       Confirmed
# 2783183 2013-09-11 13:23:00 2013-09-16 06:00:00 2013-09-16 19:00:00           WPW_T33  WPW  Transpower     RS       daily            13:00:00       Confirmed
# 2783538 2013-07-11 12:23:00 2013-09-16 07:30:00 2013-09-16 18:00:00       ADD_FDR_172  ADD  Transpower     RS       daily            10:30:00       Confirmed
# 2784387 2013-08-26 16:23:00 2013-09-16 07:00:00 2013-09-16 19:00:00         ARI_KIN_1  KIN  Transpower     RS       daily            12:00:00       Confirmed
# 2784388 2013-08-26 16:23:00 2013-09-16 07:00:00 2013-09-16 19:00:00        ARI_87_VT4  ARI  Transpower     RS       daily            12:00:00       Confirmed
# 2784391 2013-07-25 09:23:00 2013-09-16 07:00:00 2013-09-21 19:00:00         BRB_HPI_1  HPI  Transpower     RS       daily    5 days, 12:00:00       Confirmed
# 2784400 2013-09-16 06:23:00 2013-09-09 06:00:00 2013-09-17 10:00:00      KIN_FDR_2062  KIN  Transpower     RS  continuous    8 days, 04:00:00       Confirmed
# 2785321 2013-05-30 12:23:00 2013-09-16 08:00:00 2013-09-20 15:00:00         HLY_OTA_2  OTA  Transpower     RS       daily    4 days, 07:00:00       Confirmed
# 2785322 2013-05-30 12:23:00 2013-09-16 08:00:00 2013-09-20 15:00:00            TAK_T8  TAK  Transpower     RS       daily    4 days, 07:00:00       Confirmed
# 52599 2013-07-23 10:57:00  52599        New 2013-08-27 00:00:00      TKA 2013-07-23 10:57:00             0     25.2           0.0         TKA1  Genesis       Confirmed 2013-08-26 07:00:00  continuous           17:00:00    428.400000
#       2013-09-03 13:48:00  52599        New 2013-08-27 00:00:00      TKA 2013-09-03 13:48:00             0     25.2           0.0         TKA1  Genesis       Cancelled 2013-08-26 07:00:00  continuous           17:00:00    428.400000
# 52642 2013-08-02 14:17:00  52642        New 2013-08-05 18:00:00      TKA 2013-08-02 14:17:00             0      3.2          21.8         TKA1  Genesis       Confirmed 2013-08-05 07:30:00  continuous           10:30:00     33.600000
# 52643 2013-08-02 14:17:00  52643        New 2013-08-06 18:00:00      TKA 2013-08-02 14:17:00             0      3.2          21.8         TKA1  Genesis       Confirmed 2013-08-06 07:30:00  continuous           10:30:00     33.600000
# 52738 2013-08-10 14:17:00  52738        New 2013-08-16 18:00:00      TKA 2013-08-10 14:17:00             0      0.0          25.0         TKA1  Genesis       Confirmed 2013-08-13 04:00:00  continuous   3 days, 14:00:00      0.000000
#       2013-08-23 14:02:00  52738        New 2013-08-16 18:00:00      TKA 2013-08-23 14:02:00             0      0.0          25.0         TKA1  Genesis       Cancelled 2013-08-13 04:00:00  continuous   3 days, 14:00:00      0.000000
# 52741 2013-08-14 14:05:00  52741        New 2013-08-23 21:00:00      TKA 2013-08-14 14:05:00             0     18.0           7.0      TKA_STN  Genesis       Confirmed 2013-08-22 07:00:00  continuous   1 days, 14:00:00    684.000000
#       2013-08-30 14:18:00  52741        New 2013-08-23 21:00:00      TKA 2013-08-30 14:18:00             0     18.0           7.0      TKA_STN  Genesis       Cancelled 2013-08-22 07:00:00  continuous   1 days, 14:00:00    684.000000

# %%
p1 = pd.read_csv('pocp_all_1.csv', index_col = 'id')
del p1['Unnamed: 0']
p2 = pd.read_csv('pocp_all_2.csv', index_col = 'id')
del p2['Unnamed: 15']

# %%
p1.head()
# Out:
#          Assessment      Category                  End GIP/GXPs        Last Modified  MV remaining  MW Loss  MW remaining Nature     Outage Block           Owner Planning Status                Start        Type
# id
# 2164312     Changed  Transmission  2003-07-03 18:00:00      WRK  2003-06-25 09:41:00           NaN      NaN           NaN     RS  WRK_117_137_174      Transpower       Cancelled  2003-07-01 06:00:00  continuous
# 2665962     Changed  Transmission  2009-12-27 17:00:00      OTA  2009-12-07 09:33:00           NaN      NaN           NaN     RS         OTA_C_4B      Transpower       Cancelled  2000-01-03 00:00:00  continuous
# ct02_140        New    Generation  2003-05-13 23:59:00      NPL  2003-05-13 12:25:00             0      100             0    NaN            NPL_1  Contact Energy       Cancelled  2002-10-01 00:00:00  continuous
# 2149766         New  Transmission  2003-04-21 20:00:00      HAM  2003-04-08 13:45:00           NaN      NaN           NaN     RS      HAM_110BZ_A      Transpower       Confirmed  2002-12-16 08:00:00  continuous
# 2149767         New  Transmission  2003-04-21 20:00:00      HAM  2003-04-08 13:45:00           NaN      NaN           NaN     RS      HAM_110BZ_B      Transpower       Confirmed  2002-12-16 08:00:00  continuous

# %%
p2.head()
# Out:
#          Assessment           Category                  End GIP/GXPs        Last Modified  MV remaining  MW Loss  MW remaining Nature Outage Block       Owner Planning Status                Start        Type
# id
# 15281999        New  Direct Connection  2055-10-17 16:00:00  TWI2201  2005-10-17 14:05:00           NaN      NaN           NaN    NaN     HF1 HF11     Comalco       Cancelled  2005-10-17 08:30:00  continuous
# 2705100         New       Transmission  2013-11-30 17:30:00      ISL  2013-07-10 18:23:00           NaN      NaN           NaN     RS     ISL_SC_4  Transpower       Confirmed  2010-06-30 18:01:00  continuous
# 1000849         New       Transmission  2013-07-29 18:00:00      PEN  2013-07-30 06:26:00           NaN      NaN           NaN     RS       PEN_T8  Transpower       Cancelled  2012-01-16 07:00:00  continuous
# 2738451         New       Transmission  2013-05-31 18:00:00      PEN  2013-05-30 12:26:00           NaN      NaN           NaN     RS       PEN_T8  Transpower       Cancelled  2012-01-16 07:00:00  continuous
# 2740334         New       Transmission  2013-05-24 18:00:00      ALB  2013-05-25 07:26:00           NaN      NaN           NaN     RS   ALB_CB_742  Transpower       Cancelled  2012-03-30 12:00:00  continuous

# %%
p3 = p1.append(p2)

# %%
p3['End'] = p3.End.map(lambda x: dt_convert(x))
p3['Start'] = p3.Start.map(lambda x: dt_convert(x))
p3['Last Modified'] = p3['Last Modified'].map(lambda x: dt_convert(x))

# %%
p3.to_csv('pocp_all.csv')

# %%
data.head()
# Out:
#          Outage Block GIP/GXPs               Start                 End           Category        Type Nature       Owner Assessment       Last Modified Planning Status  MW remaining  MW Loss  MV remaining
# id
# 15281999     HF1 HF11  TWI2201 2005-10-17 08:30:00 2055-10-17 16:00:00  Direct Connection  continuous    NaN     Comalco        New 2005-10-17 14:05:00       Cancelled           NaN      NaN           NaN
# 2705100      ISL_SC_4      ISL 2010-06-30 18:01:00 2013-11-30 17:30:00       Transmission  continuous     RS  Transpower        New 2013-07-10 18:23:00       Confirmed           NaN      NaN           NaN
# 1000849        PEN_T8      PEN 2012-01-16 07:00:00 2013-07-29 18:00:00       Transmission  continuous     RS  Transpower        New 2013-07-30 06:26:00       Cancelled           NaN      NaN           NaN
# 2738451        PEN_T8      PEN 2012-01-16 07:00:00 2013-05-31 18:00:00       Transmission  continuous     RS  Transpower        New 2013-05-30 12:26:00       Cancelled           NaN      NaN           NaN
# 2740334    ALB_CB_742      ALB 2012-03-30 12:00:00 2013-05-24 18:00:00       Transmission  continuous     RS  Transpower        New 2013-05-25 07:26:00       Cancelled           NaN      NaN           NaN

# %%
G_caned=G_caned[G_caned.index.map(lambda x: x[1])>G_caned.Start.tolist()]

# %%
G_caned.index.map(lambda x: x[1])
# Out:
# array(['2003-04-02 14:49:00', '2012-07-31 16:58:00', '2012-06-15 02:00:00',
#        '2012-06-15 02:00:00', '2012-11-30 02:00:00', '2012-11-30 02:00:00',
#        '2012-12-01 02:00:00', '2012-12-01 02:00:00', '2013-01-23 16:52:00',
#        '2013-01-23 16:52:00', '2013-01-23 16:52:00', '2012-08-29 14:15:00',
#        '2012-11-28 14:54:00', '2012-11-28 14:54:00', '2012-11-22 02:00:00',
#        '2012-11-22 02:00:00', '2012-11-22 02:00:00', '2012-11-27 02:00:00',
#        '2012-06-14 02:00:00', '2012-11-14 02:00:00', '2012-06-14 02:00:00',
#        '2012-06-14 02:00:00', '2012-06-14 02:00:00', '2012-06-14 02:00:00',
#        '2012-06-14 02:00:00', '2012-06-14 02:00:00', '2012-06-14 02:00:00',
#        '2012-11-27 02:00:00', '2012-11-15 02:00:00', '2012-07-31 16:58:00',
#        '2012-12-17 23:35:00', '2012-03-21 10:53:00', '2012-12-17 23:35:00',
#        '2012-01-27 12:21:00', '2012-12-17 23:35:00', '2012-12-22 05:04:00',
#        '2012-10-05 23:36:00', '2012-08-16 15:07:00', '2012-10-05 23:36:00',
#        '2012-08-16 15:07:00', '2012-08-16 15:07:00', '2012-10-05 23:36:00',
#        '2012-08-23 00:36:00', '2012-08-16 15:07:00', '2012-08-16 15:07:00',
#        '2012-02-09 07:25:00', '2012-08-16 15:07:00', '2012-08-16 15:07:00',
#        '2012-09-24 23:36:00', '2012-08-16 15:07:00', '2012-10-31 11:36:00',
#        '2012-09-19 11:36:00', '2012-09-25 11:36:00', '2012-08-21 12:36:00',
#        '2012-08-21 12:36:00', '2012-08-21 12:36:00', '2012-08-21 12:36:00',
#        '2012-09-25 11:36:00', '2012-08-16 15:07:00', '2012-08-16 15:07:00',
#        '2012-05-22 12:14:00', '2012-09-25 11:36:00', '2012-09-19 11:36:00',
#        '2012-08-21 12:36:00', '2012-08-21 12:36:00', '2012-08-21 12:36:00',
#        '2012-08-16 15:07:00', '2012-08-16 15:07:00', '2012-08-16 15:07:00',
#        '2012-02-09 07:25:00', '2012-08-16 15:07:00', '2012-02-09 07:25:00',
#        '2012-12-06 11:37:00', '2012-09-19 23:36:00', '2012-07-28 17:53:00',
#        '2012-08-16 15:07:00', '2012-08-16 15:07:00', '2011-11-29 12:20:00',
#        '2012-08-16 15:07:00', '2012-08-16 15:07:00', '2012-08-16 15:07:00',
#        '2012-08-16 15:07:00', '2012-08-16 15:07:00', '2012-11-30 02:00:00',
#        '2012-11-21 02:00:00', '2012-11-30 02:00:00', '2012-11-21 02:00:00',
#        '2012-12-08 01:59:00', '2012-11-28 02:00:00', '2013-01-07 11:36:00'], dtype=object)

# %%
GT={'ABY': 'Hydro','ANC': 'Thermal','ARA': 'Hydro','ARG': 'Hydro','ARI': 'Hydro','ASB': 'Hydro','ATI': 'Hydro','AVI': 'Hydro','BEN': 'Hydro','BLN': 'Hydro',\
    'BPE': 'Wind','BRB': 'Thermal','BWK': 'Hydro','COB': 'Hydro','COL': 'Hydro','CST': 'Hydro','CYD': 'Hydro','DOB': 'Hydro','HAM': 'Thermal','HKK': 'Hydro',\
    'HLY': 'Thermal','HUI': 'Hydro','HWA': 'Hydro','HWB': 'Wind','KAG': 'Geothermal','KAW': 'Geothermal','KIN':'Thermal','KPO': 'Hydro','KTW': 'Hydro','KUM': 'Hydro',\
    'LTN': 'Wind','MAN': 'Hydro','MAT': 'Hydro','MDN': 'Thermal','MTI': 'Hydro','NAP': 'Geothermal','NPL': 'Thermal','NSY': 'Hydro','OHA': 'Hydro','OHB': 'Hydro',\
    'OHC': 'Hydro','OHK': 'Hydro','OKI': 'Geothermal','OTA': 'Thermal','PPI': 'Geothermal','PRI': 'Hydro','ROT': 'Thermal','ROX': 'Hydro','RPO': 'Hydro',\
    'SFD': 'Thermal','SWN': 'Thermal','TAA': 'Geothermal','TAP': 'Wind','TGA': 'Hydro','TKA': 'Hydro','TKB': 'Hydro','TKU': 'Hydro','TMU': 'Thermal','TUI': 'Hydro',\
    'TUK': 'Wind','TWC': 'Wind','WHI': 'Thermal','WHL': 'Wind','WKM': 'Hydro','WPA': 'Hydro','WRK': 'Geothermal','WTK': 'Hydro','WWD': 'Wind'}

# %%
p.generation_type_map()

# %%
x1=[]
x2=[]
for g in set(GT.keys()) - set(p.GT):
    x1.append(g)
    x2.append(GT[g])

dict(zip(x1,x2))
# Out:
# {'ABY': 'Hydro',
#  'ANC': 'Thermal',
#  'BLN': 'Hydro',
#  'BPE': 'Wind',
#  'BRB': 'Thermal',
#  'CST': 'Hydro',
#  'DOB': 'Hydro',
#  'HAM': 'Thermal',
#  'HKK': 'Hydro',
#  'HUI': 'Hydro',
#  'HWB': 'Wind',
#  'KAG': 'Geothermal',
#  'KTW': 'Hydro',
#  'KUM': 'Hydro',
#  'LTN': 'Wind',
#  'NSY': 'Hydro',
#  'PRI': 'Hydro',
#  'TAA': 'Geothermal',
#  'TAP': 'Wind',
#  'TGA': 'Hydro',
#  'TUK': 'Wind',
#  'WHL': 'Wind'}

# %%
def generation_type_map(self):
    query = "Select * from com.MAP_Generating_plant"
    gens = sql.read_frame(query, self.con)
    gens = gens[gens['Connection_Type']=='G']
    GT = gens.set_index('POC').Generation_Type.reset_index()
    GT['POC'] = GT.POC.map(lambda x: x[0:3])
    GT = GT.drop_duplicates().set_index('POC').Generation_Type
    GT.ix['KAW'] = 'Geothermal'
    self.GT = GT.to_dict()

# %%
island = sql.read_frame("Select * from com.MAP_PNode_to_POC_and_island", con)
island_map = island.set_index('POC').Island
island_map.index=island_map.index.map(lambda x: x[0:3])
island_map = island_map.reset_index().drop_duplicates().set_index('index').Island.to_dict()

# %%
island_map
# Out:
# {'ABY': 'SI',
#  'ADD': 'SI',
#  'ALB': 'NI',
#  'APS': 'SI',
#  'ARA': 'NI',
#  'ARG': 'SI',
#  'ARI': 'NI',
#  'ASB': 'SI',
#  'ASY': 'SI',
#  'ATI': 'NI',
#  'ATU': 'SI',
#  'AVI': 'SI',
#  'BAL': 'SI',
#  'BDE': 'SI',
#  'BEN': 'SI',
#  'BHL': 'NI',
#  'BLN': 'SI',
#  'BOB': 'NI',
#  'BPC': 'SI',
#  'BPD': 'SI',
#  'BPE': 'NI',
#  'BPT': 'SI',
#  'BRB': 'NI',
#  'BRK': 'NI',
#  'BRY': 'SI',
#  'BWK': 'SI',
#  'CBG': 'NI',
#  'CLH': 'SI',
#  'CML': 'SI',
#  'COB': 'SI',
#  'COL': 'SI',
#  'CPK': 'NI',
#  'CST': 'NI',
#  'CUL': 'SI',
#  'CYD': 'SI',
#  'DAR': 'NI',
#  'DOB': 'SI',
#  'DRY': 'NI',
#  'DVK': 'NI',
#  'EDG': 'NI',
#  'EDN': 'SI',
#  'FHL': 'NI',
#  'FKN': 'SI',
#  'GFD': 'NI',
#  'GIS': 'NI',
#  'GLN': 'NI',
#  'GNY': 'SI',
#  'GOR': 'SI',
#  'GYM': 'SI',
#  'GYT': 'NI',
#  'HAM': 'NI',
#  'HAT': 'NI',
#  'HAY': 'NI',
#  'HEN': 'NI',
#  'HEP': 'NI',
#  'HIN': 'NI',
#  'HKK': 'SI',
#  'HLY': 'NI',
#  'HOR': 'SI',
#  'HPI': 'NI',
#  'HTI': 'NI',
#  'HUI': 'NI',
#  'HWA': 'NI',
#  'HWB': 'SI',
#  'IGH': 'SI',
#  'INV': 'SI',
#  'ISL': 'SI',
#  'KAI': 'SI',
#  'KAW': 'NI',
#  'KBT': 'SI',
#  'KBY': 'SI',
#  'KEN': 'NI',
#  'KIK': 'SI',
#  'KIN': 'NI',
#  'KKA': 'SI',
#  'KMO': 'NI',
#  'KOE': 'NI',
#  'KPA': 'NI',
#  'KPO': 'NI',
#  'KPU': 'NI',
#  'KTA': 'NI',
#  'KUM': 'SI',
#  'KWA': 'NI',
#  'LFD': 'NI',
#  'LIV': 'SI',
#  'LTN': 'NI',
#  'MAN': 'SI',
#  'MAT': 'NI',
#  'MCH': 'SI',
#  'MDN': 'NI',
#  'MER': 'NI',
#  'MGM': 'NI',
#  'MHO': 'NI',
#  'MHT': 'NI',
#  'MKE': 'NI',
#  'MKT': 'NI',
#  'MLG': 'NI',
#  'MLN': 'SI',
#  'MLT': 'SI',
#  'MNG': 'NI',
#  'MNI': 'NI',
#  'MOT': 'SI',
#  'MPE': 'NI',
#  'MPI': 'SI',
#  'MRA': 'NI',
#  'MST': 'NI',
#  'MTI': 'NI',
#  'MTM': 'NI',
#  'MTN': 'NI',
#  'MTO': 'NI',
#  'MTR': 'NI',
#  'MVE': 'NI',
#  'NAP': 'NI',
#  'NAT': 'NI',
#  'NGA': 'NI',
#  'NMA': 'SI',
#  'NPK': 'NI',
#  'NPL': 'NI',
#  'NSY': 'SI',
#  'OAM': 'SI',
#  'OHA': 'SI',
#  'OHB': 'SI',
#  'OHC': 'SI',
#  'OHK': 'NI',
#  'OHW': 'NI',
#  'OKE': 'NI',
#  'OKI': 'NI',
#  'OKN': 'NI',
#  'ONG': 'NI',
#  'OPI': 'SI',
#  'OPK': 'NI',
#  'ORO': 'SI',
#  'OTA': 'NI',
#  'OTI': 'SI',
#  'OWH': 'NI',
#  'PAK': 'NI',
#  'PAL': 'SI',
#  'PAO': 'NI',
#  'PAP': 'SI',
#  'PEN': 'NI',
#  'PIE': 'NI',
#  'PNI': 'NI',
#  'PPI': 'NI',
#  'PPT': 'NI',
#  'PRM': 'NI',
#  'RDF': 'NI',
#  'RFC': 'SI',
#  'RFN': 'SI',
#  'ROS': 'NI',
#  'ROT': 'NI',
#  'ROX': 'SI',
#  'RPO': 'NI',
#  'RTO': 'NI',
#  'RTR': 'NI',
#  'SBK': 'SI',
#  'SDN': 'SI',
#  'SFD': 'NI',
#  'SPN': 'SI',
#  'STK': 'SI',
#  'STU': 'SI',
#  'SVL': 'NI',
#  'SWN': 'NI',
#  'TAK': 'NI',
#  'TGA': 'NI',
#  'THI': 'NI',
#  'TIM': 'SI',
#  'TKA': 'SI',
#  'TKB': 'SI',
#  'TKH': 'NI',
#  'TKR': 'NI',
#  'TKU': 'NI',
#  'TMH': 'SI',
#  'TMI': 'NI',
#  'TMK': 'SI',
#  'TMN': 'NI',
#  'TMU': 'NI',
#  'TNG': 'NI',
#  'TRK': 'NI',
#  'TUI': 'NI',
#  'TWC': 'NI',
#  'TWH': 'NI',
#  'TWI': 'SI',
#  'TWT': 'NI',
#  'TWZ': 'SI',
#  'UHT': 'NI',
#  'UTK': 'SI',
#  'WAI': 'NI',
#  'WDV': 'NI',
#  'WEL': 'NI',
#  'WES': 'NI',
#  'WGN': 'NI',
#  'WHI': 'NI',
#  'WHU': 'NI',
#  'WIL': 'NI',
#  'WIR': 'NI',
#  'WKM': 'NI',
#  'WKO': 'NI',
#  'WMG': 'SI',
#  'WPA': 'NI',
#  'WPR': 'SI',
#  'WPT': 'SI',
#  'WPW': 'NI',
#  'WRA': 'NI',
#  'WRD': 'NI',
#  'WRK': 'NI',
#  'WTK': 'SI',
#  'WTU': 'NI',
#  'WVY': 'NI',
#  'WWD': 'NI'}

# %%
# Out:
#     Island
# ABY     SI
# ALB     NI

# %%
island_map
# Out:
# {'Island': {'ABY': 'SI',
#   'ADD': 'SI',
#   'ALB': 'NI',
#   'APS': 'SI',
#   'ARA': 'NI',
#   'ARG': 'SI',
#   'ARI': 'NI',
#   'ASB': 'SI',
#   'ASY': 'SI',
#   'ATI': 'NI',
#   'ATU': 'SI',
#   'AVI': 'SI',
#   'BAL': 'SI',
#   'BDE': 'SI',
#   'BEN': 'SI',
#   'BHL': 'NI',
#   'BLN': 'SI',
#   'BOB': 'NI',
#   'BPC': 'SI',
#   'BPD': 'SI',
#   'BPE': 'NI',
#   'BPT': 'SI',
#   'BRB': 'NI',
#   'BRK': 'NI',
#   'BRY': 'SI',
#   'BWK': 'SI',
#   'CBG': 'NI',
#   'CLH': 'SI',
#   'CML': 'SI',
#   'COB': 'SI',
#   'COL': 'SI',
#   'CPK': 'NI',
#   'CST': 'NI',
#   'CUL': 'SI',
#   'CYD': 'SI',
#   'DAR': 'NI',
#   'DOB': 'SI',
#   'DRY': 'NI',
#   'DVK': 'NI',
#   'EDG': 'NI',
#   'EDN': 'SI',
#   'FHL': 'NI',
#   'FKN': 'SI',
#   'GFD': 'NI',
#   'GIS': 'NI',
#   'GLN': 'NI',
#   'GNY': 'SI',
#   'GOR': 'SI',
#   'GYM': 'SI',
#   'GYT': 'NI',
#   'HAM': 'NI',
#   'HAT': 'NI',
#   'HAY': 'NI',
#   'HEN': 'NI',
#   'HEP': 'NI',
#   'HIN': 'NI',
#   'HKK': 'SI',
#   'HLY': 'NI',
#   'HOR': 'SI',
#   'HPI': 'NI',
#   'HTI': 'NI',
#   'HUI': 'NI',
#   'HWA': 'NI',
#   'HWB': 'SI',
#   'IGH': 'SI',
#   'INV': 'SI',
#   'ISL': 'SI',
#   'KAI': 'SI',
#   'KAW': 'NI',
#   'KBT': 'SI',
#   'KBY': 'SI',
#   'KEN': 'NI',
#   'KIK': 'SI',
#   'KIN': 'NI',
#   'KKA': 'SI',
#   'KMO': 'NI',
#   'KOE': 'NI',
#   'KPA': 'NI',
#   'KPO': 'NI',
#   'KPU': 'NI',
#   'KTA': 'NI',
#   'KUM': 'SI',
#   'KWA': 'NI',
#   'LFD': 'NI',
#   'LIV': 'SI',
#   'LTN': 'NI',
#   'MAN': 'SI',
#   'MAT': 'NI',
#   'MCH': 'SI',
#   'MDN': 'NI',
#   'MER': 'NI',
#   'MGM': 'NI',
#   'MHO': 'NI',
#   'MHT': 'NI',
#   'MKE': 'NI',
#   'MKT': 'NI',
#   'MLG': 'NI',
#   'MLN': 'SI',
#   'MLT': 'SI',
#   'MNG': 'NI',
#   'MNI': 'NI',
#   'MOT': 'SI',
#   'MPE': 'NI',
#   'MPI': 'SI',
#   'MRA': 'NI',
#   'MST': 'NI',
#   'MTI': 'NI',
#   'MTM': 'NI',
#   'MTN': 'NI',
#   'MTO': 'NI',
#   'MTR': 'NI',
#   'MVE': 'NI',
#   'NAP': 'NI',
#   'NAT': 'NI',
#   'NGA': 'NI',
#   'NMA': 'SI',
#   'NPK': 'NI',
#   'NPL': 'NI',
#   'NSY': 'SI',
#   'OAM': 'SI',
#   'OHA': 'SI',
#   'OHB': 'SI',
#   'OHC': 'SI',
#   'OHK': 'NI',
#   'OHW': 'NI',
#   'OKE': 'NI',
#   'OKI': 'NI',
#   'OKN': 'NI',
#   'ONG': 'NI',
#   'OPI': 'SI',
#   'OPK': 'NI',
#   'ORO': 'SI',
#   'OTA': 'NI',
#   'OTI': 'SI',
#   'OWH': 'NI',
#   'PAK': 'NI',
#   'PAL': 'SI',
#   'PAO': 'NI',
#   'PAP': 'SI',
#   'PEN': 'NI',
#   'PIE': 'NI',
#   'PNI': 'NI',
#   'PPI': 'NI',
#   'PPT': 'NI',
#   'PRM': 'NI',
#   'RDF': 'NI',
#   'RFC': 'SI',
#   'RFN': 'SI',
#   'ROS': 'NI',
#   'ROT': 'NI',
#   'ROX': 'SI',
#   'RPO': 'NI',
#   'RTO': 'NI',
#   'RTR': 'NI',
#   'SBK': 'SI',
#   'SDN': 'SI',
#   'SFD': 'NI',
#   'SPN': 'SI',
#   'STK': 'SI',
#   'STU': 'SI',
#   'SVL': 'NI',
#   'SWN': 'NI',
#   'TAK': 'NI',
#   'TGA': 'NI',
#   'THI': 'NI',
#   'TIM': 'SI',
#   'TKA': 'SI',
#   'TKB': 'SI',
#   'TKH': 'NI',
#   'TKR': 'NI',
#   'TKU': 'NI',
#   'TMH': 'SI',
#   'TMI': 'NI',
#   'TMK': 'SI',
#   'TMN': 'NI',
#   'TMU': 'NI',
#   'TNG': 'NI',
#   'TRK': 'NI',
#   'TUI': 'NI',
#   'TWC': 'NI',
#   'TWH': 'NI',
#   'TWI': 'SI',
#   'TWT': 'NI',
#   'TWZ': 'SI',
#   'UHT': 'NI',
#   'UTK': 'SI',
#   'WAI': 'NI',
#   'WDV': 'NI',
#   'WEL': 'NI',
#   'WES': 'NI',
#   'WGN': 'NI',
#   'WHI': 'NI',
#   'WHU': 'NI',
#   'WIL': 'NI',
#   'WIR': 'NI',
#   'WKM': 'NI',
#   'WKO': 'NI',
#   'WMG': 'SI',
#   'WPA': 'NI',
#   'WPR': 'SI',
#   'WPT': 'SI',
#   'WPW': 'NI',
#   'WRA': 'NI',
#   'WRD': 'NI',
#   'WRK': 'NI',
#   'WTK': 'SI',
#   'WTU': 'NI',
#   'WVY': 'NI',
#   'WWD': 'NI'}}

# %%
island_map.reset_index().drop_duplicates().set_index('index')
# Out:
#       Island
# index
# ABY       SI
# ADD       SI
# ALB       NI
# APS       SI
# ARA       NI
# ARG       SI
# ARI       NI
# ASB       SI
# ASY       SI
# ATI       NI
# ATU       SI
# AVI       SI
# BAL       SI
# BDE       SI
# BEN       SI
# BHL       NI
# BLN       SI
# BOB       NI
# BPC       SI
# BPD       SI
# BPE       NI
# BPT       SI
# BRB       NI
# BRK       NI
# BRY       SI
# BWK       SI
# CBG       NI
# CLH       SI
# CML       SI
# COB       SI
# COL       SI
# CPK       NI
# CST       NI
# CUL       SI
# CYD       SI
# DAR       NI
# DOB       SI
# DRY       NI
# DVK       NI
# EDG       NI
# EDN       SI
# FHL       NI
# FKN       SI
# GFD       NI
# GIS       NI
# GLN       NI
# GNY       SI
# GOR       SI
# GYM       SI
# GYT       NI
# HAM       NI
# HAT       NI
# HAY       NI
# HEN       NI
# HEP       NI
# HIN       NI
# HKK       SI
# HLY       NI
# HOR       SI
# HPI       NI
# HTI       NI
# HUI       NI
# HWA       NI
# HWB       SI
# IGH       SI
# INV       SI
# ISL       SI
# KAI       SI
# KAW       NI
# KBT       SI
# KBY       SI
# KEN       NI
# KIK       SI
# KIN       NI
# KKA       SI
# KMO       NI
# KOE       NI
# KPA       NI
# KPO       NI
# KPU       NI
# KTA       NI
# KUM       SI
# KWA       NI
# LFD       NI
# LIV       SI
# LTN       NI
# MAN       SI
# MAT       NI
# MCH       SI
# MDN       NI
# MER       NI
# MGM       NI
# MHO       NI
# MHT       NI
# MKE       NI
# MKT       NI
# MLG       NI
# MLN       SI
# MLT       SI
# MNG       NI
# MNI       NI
# MOT       SI
# MPE       NI
# MPI       SI
# MRA       NI
# MST       NI
# MTI       NI
# MTM       NI
# MTN       NI
# MTO       NI
# MTR       NI
# MVE       NI
# NAP       NI
# NAT       NI
# NGA       NI
# NMA       SI
# NPK       NI
# NPL       NI
# NSY       SI
# OAM       SI
# OHA       SI
# OHB       SI
# OHC       SI
# OHK       NI
# OHW       NI
# OKE       NI
# OKI       NI
# OKN       NI
# ONG       NI
# OPI       SI
# OPK       NI
# ORO       SI
# OTA       NI
# OTI       SI
# OWH       NI
# PAK       NI
# PAL       SI
# PAO       NI
# PAP       SI
# PEN       NI
# PIE       NI
# PNI       NI
# PPI       NI
# PPT       NI
# PRM       NI
# RDF       NI
# RFC       SI
# RFN       SI
# ROS       NI
# ROT       NI
# ROX       SI
# RPO       NI
# RTO       NI
# RTR       NI
# SBK       SI
# SDN       SI
# SFD       NI
# SPN       SI
# STK       SI
# STU       SI
# SVL       NI
# SWN       NI
# TAK       NI
# TGA       NI
# THI       NI
# TIM       SI
# TKA       SI
# TKB       SI
# TKH       NI
# TKR       NI
# TKU       NI
# TMH       SI
# TMI       NI
# TMK       SI
# TMN       NI
# TMU       NI
# TNG       NI
# TRK       NI
# TUI       NI
# TWC       NI
# TWH       NI
# TWI       SI
# TWT       NI
# TWZ       SI
# UHT       NI
# UTK       SI
# WAI       NI
# WDV       NI
# WEL       NI
# WES       NI
# WGN       NI
# WHI       NI
# WHU       NI
# WIL       NI
# WIR       NI
# WKM       NI
# WKO       NI
# WMG       SI
# WPA       NI
# WPR       SI
# WPT       SI
# WPW       NI
# WRA       NI
# WRD       NI
# WRK       NI
# WTK       SI
# WTU       NI
# WVY       NI
# WWD       NI

# %%
p.Gc
# Out:
#                                               Start                 End  MW Loss Outage Block  GIP           Owner  Nature        Type            Duration Planning Status
# id    id    Last Modified
# 1984  1984  2013-09-04 14:07:00 2013-09-02 07:00:00 2013-09-20 17:00:00    108.0        CYD_4  CYD  Contact Energy       0  continuous   18 days, 10:00:00       Confirmed
# 2338  2338  2013-09-09 11:43:00 2013-07-26 08:00:00 2013-09-24 16:00:00     10.0        TAA_1  TAA  Contact Energy       0  continuous   60 days, 08:00:00       Confirmed
# 2611  2611  2013-09-09 11:43:00 2013-08-06 11:00:00 2013-09-16 17:00:00    100.0       SFD_22  SFD  Contact Energy       0  continuous   41 days, 06:00:00       Confirmed
# 2693  2693  2013-09-04 14:07:00 2013-09-16 09:00:00 2013-09-26 18:00:00     11.0        WRK_8  WRK  Contact Energy       0  continuous   10 days, 09:00:00       Confirmed
# 2705  2705  2013-09-04 14:07:00 2013-09-11 08:00:00 2013-09-20 16:00:00     12.0        TAA_2  TAA  Contact Energy       0  continuous    9 days, 08:00:00       Confirmed
# 39594 39594 2013-08-13 23:36:00 2013-08-19 07:00:00 2013-09-30 19:00:00     35.2        MTI_8  MTI    Mighty River       0  continuous   42 days, 12:00:00       Confirmed
# 39668 39668 2012-09-19 08:06:00 2013-04-29 06:00:00 2013-10-20 18:00:00     26.5        OHK_3  OHK    Mighty River       0  continuous  174 days, 12:00:00       Confirmed
# 41200 41200 2013-08-28 11:36:00 2013-07-28 15:00:00 2013-11-14 17:00:00     24.0        ARI_6  ARI    Mighty River       0  continuous  109 days, 02:00:00       Confirmed
# 41681 41681 2013-09-11 11:36:00 2013-09-12 07:30:00 2013-09-25 19:00:00     18.5        ATI_4  ATI    Mighty River       0  continuous   13 days, 11:30:00       Confirmed
# 42325 42325 2012-12-01 02:00:00 2013-09-09 06:00:00 2013-09-18 20:00:00    121.5         MAN3  MAN        Meridian       0  continuous    9 days, 14:00:00       Confirmed
